# %% [markdown]
# # Classic U-net with VGG16 backbone and using simple geometric transformations as data augmentation

# %% [markdown]
# **Structure of the used model**
# * U-net like structure with transfer learning:
#   * Encoder: VGG 16 pre-trained on imagenet.
#   * Decoder: U-net like

# %% [markdown]
# <img src="https://ws3.sinaimg.cn/large/006tNbRwgy1fxspbgwxx8j312z0h5764.jpg"
#           align="center"
#           width="800" />

# %% [markdown]
# ## Load general packages. There some more package loading for the more specific tasks

# %%
colab = True

# %%
# for file handling
import os
from pathlib import Path

# Only if working from Google Colab
if colab:
    # Mount the Google Drive to reach its data
    from google.colab import drive
    drive.mount('/content/gdrive')
    os.chdir('/content/gdrive/My Drive')
    # making sure we used the newest versions
    # !pip install --upgrade keras 
    # !pip install --upgrade tensorflow

import sys
sys.path.append('Final_solution')    

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# for numeric calculations
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

# for data handling
import pandas as pd

# for plotting the preprocessed images and the output images and masks
from skimage.measure import find_contours
from skimage.util.montage import montage2d
montage_rgb = lambda x: np.stack([montage2d(x[:, :, :, i]) for i in range(x.shape[3])], -1)

# %% [markdown]
# **log dictionary is used to make a log file after every parameters is collected**

# %%
log = {}

# %% [markdown]
# ## Data handling and preprocessing

# %%
from data_utils import load_paths, make_split, make_generators
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# **Define the image parameters and the batch size**

# %%
image_parameters = dict(batch_size = 4,
                        image_size = (224, 224))
image_parameters['input_shape'] = image_parameters['image_size'] + (3,)

log['image_parameters'] = image_parameters

# %%
data_df = load_paths(root='ISIC2018')
train_df, valid_df, test_df = make_split(data_df, train_size=2080, valid_size=264)

print('images:', len(data_df),'train images:', len(train_df), 'valid images:', len(valid_df),'test images:', len(test_df))
data_df.head()
# Out:
# images: 2594 train images: 2080 valid images: 264 test images: 250
#                                              image_path      image_id  \
# 2001  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000000
# 1998  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000001
# 1999  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000003
# 2004  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000004
# 2003  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000006
#
#         image_filename                                         task1_path  \
# 2001  ISIC_0000000.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 1998  ISIC_0000001.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 1999  ISIC_0000003.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 2004  ISIC_0000004.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 2003  ISIC_0000006.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
#
#                      task1_filename
# 2001  ISIC_0000000_segmentation.png
# 1998  ISIC_0000001_segmentation.png
# 1999  ISIC_0000003_segmentation.png
# 2004  ISIC_0000004_segmentation.png
# 2003  ISIC_0000006_segmentation.png

# %%
data_augmentations_args = dict(rotation_range=270,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               zoom_range=0.2,
                               data_format = 'channels_last',
                               fill_mode='nearest')
log['data_augmentations_args'] = data_augmentations_args

# Set the ImageDataGenerator arguments in a dictionary
data_gen_args = dict(data_format = 'channels_last',
                     preprocessing_function = lambda x: preprocess_input(x, data_format='channels_last', mode='tf'))
log['ImageDataGenerator_image_args'] = data_gen_args

# Use the same for the masks and images. (We use same seed value too.)
mask_gen_args = data_gen_args.copy()
mask_gen_args['preprocessing_function'] = lambda x: x/255.0
log['ImageDataGenerator_mask_args'] = mask_gen_args

# %%
# set the flow_from_directory arguments in a dictionary
image_flow_from_dataframe_args = dict(seed = 999,
                                      class_mode=None,
                                      batch_size=image_parameters['batch_size'],
                                      x_col='image_filename',
                                      color_mode = 'rgb',
                                      target_size = image_parameters['image_size'])
log['FlowFromDataframe_image_args'] = image_flow_from_dataframe_args

# use the same arguments for the masks and images. (We use same seed value too.)
mask_flow_from_dataframe_args = image_flow_from_dataframe_args.copy()
mask_flow_from_dataframe_args['x_col'] = 'task1_filename'
mask_flow_from_dataframe_args['color_mode'] = 'grayscale'
log['FlowFromDataframe_mask_args'] = mask_flow_from_dataframe_args

# %%
train_generator, valid_generator, test_generator = make_generators(data_gen_args, mask_gen_args, image_flow_from_dataframe_args, mask_flow_from_dataframe_args, train_df, valid_df, test_df)
# Out:
# Found 2080 images.
# Found 2080 images.
# Found 264 images.
# Found 264 images.
# Found 250 images.
# Found 250 images.

# %%
data_gen_args.update(data_augmentations_args)
mask_gen_args.update(data_augmentations_args)

train_augmented_generator, valid_augmented_generator, test_augmented_generator = make_generators(data_gen_args, mask_gen_args, image_flow_from_dataframe_args, mask_flow_from_dataframe_args, train_df, valid_df, test_df)
# Out:
# Found 2080 images.
# Found 2080 images.
# Found 264 images.
# Found 264 images.
# Found 250 images.
# Found 250 images.

# %%
probe_image, probe_mask = next(train_augmented_generator)

print('image', probe_image.shape, probe_image.dtype, probe_image.min(), probe_image.max())
print('mask', probe_mask.shape, probe_mask.dtype, probe_mask.min(), probe_mask.max())

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (20, 10))

ax1.imshow(montage_rgb(probe_image)*0.5+0.5)
ax1.imshow(montage2d(probe_mask[:, :, :, 0]), cmap='gray',alpha=0.3)
ax1.set_title('Images VS Masks')

ax2.imshow(montage_rgb(probe_image)*0.5+0.5)
ax2.set_title('Images')

ax3.imshow(montage2d(probe_mask[:, :, :, 0]), cmap='gray')
ax3.set_title('Masks')

plt.show()
# Out:
# image (4, 224, 224, 3) float32 -0.90693676 0.997614
# mask (4, 224, 224, 1) float32 0.0 1.0

# %% [markdown]
# ## Build the model

# %% [markdown]
# **import the necessary packages**

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, Activation, MaxPooling2D, Concatenate, UpSampling2D, BatchNormalization, Dropout, Add

from keras.applications.vgg16 import VGG16

from model_utils import get_layer_size_dict, concat_layers_dict, save_log

# %% [markdown]
# **Loading the pretrained VGG16 network. This is our encoder part.**

# %%
VGG16_args = dict(input_shape = image_parameters['input_shape'], 
                  include_top = False, 
                  weights = 'imagenet')
log['VGG16_args'] = VGG16_args

vgg16 = VGG16(**VGG16_args)

# %% [markdown]
# **Collect the layer sizes for the decoder part, inspect the structue of the pre-trained model**

# %%
layer_size_dict = get_layer_size_dict(vgg16)

for shape, layer_names in zip(layer_size_dict.keys(), layer_size_dict.values()):
    print('Otuput shape:', shape, 'Layer names:', [temp.name for temp in layer_names])
# Out:
# Otuput shape: (224, 224) Layer names: ['input_2', 'block1_conv1', 'block1_conv2']
# Otuput shape: (112, 112) Layer names: ['block1_pool', 'block2_conv1', 'block2_conv2']
# Otuput shape: (56, 56) Layer names: ['block2_pool', 'block3_conv1', 'block3_conv2', 'block3_conv3']
# Otuput shape: (28, 28) Layer names: ['block3_pool', 'block4_conv1', 'block4_conv2', 'block4_conv3']
# Otuput shape: (14, 14) Layer names: ['block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3']
# Otuput shape: (7, 7) Layer names: ['block5_pool']

# %%
concat_layers = concat_layers_dict(layer_size_dict)

for shape, output in zip(concat_layers.keys(), concat_layers.values()):
    print('Output shape: ', shape, 'Last output: ', output)
# Out:
# Output shape:  (224, 224) Last output:  Tensor("block1_conv2_1/Relu:0", shape=(?, 224, 224, 64), dtype=float32)
# Output shape:  (112, 112) Last output:  Tensor("block2_conv2_1/Relu:0", shape=(?, 112, 112, 128), dtype=float32)
# Output shape:  (56, 56) Last output:  Tensor("block3_conv3_1/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# Output shape:  (28, 28) Last output:  Tensor("block4_conv3_1/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# Output shape:  (14, 14) Last output:  Tensor("block5_conv3_1/Relu:0", shape=(?, 14, 14, 512), dtype=float32)
# Output shape:  (7, 7) Last output:  Tensor("block5_pool_1/MaxPool:0", shape=(?, 7, 7, 512), dtype=float32)

# %% [markdown]
# **Build the decoder part**

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True, n_layers=2):

    x = input_tensor
    for i in range(n_layers):
        x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
        if batchnorm:
            x = BatchNormalization()(x)
        x = Activation("elu")(x)
    return x

# %%
x = vgg16.output

# Bottleneck
##########################################################################

x = conv2d_block(x, 512)

# Decoder
##########################################################################

x = UpSampling2D(size=(2,2))(x) 
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])
x = conv2d_block(x, 512, 3, True, 3)

##########################################################################

x = UpSampling2D(size=(2,2))(x) 
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])
x = conv2d_block(x, 512, 3, True, 3)

##########################################################################

x = UpSampling2D(size=(2,2))(x) 
x = Conv2D(256, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])
x = conv2d_block(x, 256, 3, True, 3)

##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Conv2D(128, (3, 3), padding='same')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = conv2d_block(x, 128)

##########################################################################

x = UpSampling2D(size=(2,2))(x) 
x = Conv2D(64, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = conv2d_block(x, 64)

##########################################################################

x = conv2d_block(x, 32, 3, True, 1)

x = Conv2D(1, (1, 1), padding='same', kernel_initializer ='he_normal')(x)
x = Activation('sigmoid')(x)

model_final = Model(inputs=vgg16.input, outputs=x)

# %%
model_final.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 7, 7, 512)    2359808     block5_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 7, 7, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 7, 7, 512)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 7, 7, 512)    2359808     activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 7, 7, 512)    2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 7, 7, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 14, 14, 512)  0           activation_19[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 1024) 0           up_sampling2d_6[0][0]
#                                                                  block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 512)  4719104     concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 512)  2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 14, 512)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 512)  2359808     activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 512)  2048        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 14, 512)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 512)  2359808     activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 512)  2048        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 14, 512)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 28, 28, 512)  0           activation_22[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 1024) 0           up_sampling2d_7[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 512)  2048        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 512)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 512)  2359808     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 512)  2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 512)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 512)  2359808     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 512)  2048        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 512)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 56, 56, 512)  0           activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 256)  1179904     up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 56, 56, 512)  0           conv2d_29[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 56, 56, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 56, 56, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 56, 56, 256)  1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 56, 56, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 256)  590080      activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 56, 56, 256)  1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 56, 56, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 112, 112, 256 0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 112, 112, 128 295040      up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 112, 112, 256 0           conv2d_33[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 112, 112, 128 295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 112, 112, 128 512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 112, 112, 128 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 112, 112, 128 147584      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 112, 112, 128 512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 112, 112, 128 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 224, 224, 128 0           activation_30[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 224, 224, 64) 73792       up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 224, 224, 128 0           conv2d_36[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 224, 224, 64) 73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 224, 224, 64) 256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 224, 224, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 224, 224, 64) 36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 224, 224, 64) 256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 224, 224, 64) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 224, 224, 32) 18464       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 224, 224, 32) 128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 224, 224, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 224, 224, 1)  33          activation_33[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 224, 224, 1)  0           conv2d_40[0][0]
# ==================================================================================================
# Total params: 42,813,505
# Trainable params: 42,802,945
# Non-trainable params: 10,560
# __________________________________________________________________________________________________

# %%
from losses import dice_log_bce_loss
from keras.losses import binary_crossentropy

from metrics import dice, jaccard, precision, sensitivity, specificity

from callbacks import ProgeressPlot, ProgressSave
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau, Callback, CSVLogger, CallbackList

from keras.optimizers import SGD, Adam, Nadam

# %%
save_dir = 'Final_solution/saved_models' + '/' + 'Test_Unet_VGG16_classic_data_augmentation_not_freezed'

# Set which layers can learn
for layer in vgg16.layers[1:]:
    layer.trainable = True

# Set callbacks
progress_save = ProgressSave(file_mode='w', save_dir=save_dir, filename='history.csv')

progress_plot = ProgeressPlot(next(test_generator), monitor='val_jaccard', save_dir=save_dir)

csv_logger = CSVLogger(os.path.join(save_dir, 'history_csv_logger.csv'), append=True)

ReduceLROnPlateau_args = dict(monitor='val_jaccard',
                              mode='auto',
                              patience=2,
                              factor=0.5,
                              min_lr=0.000001,
                              verbose=1)
log['ReduceLROnPlateau_args'] = ReduceLROnPlateau_args
reduce_lr = ReduceLROnPlateau(**ReduceLROnPlateau_args)

checkpoint_path = save_dir + '/' + 'data_augmentation_not_freezed_best' + '.hdf5'
ModelCheckpoint_args = dict(monitor='val_jaccard',
                            save_best_only = True,  
                            save_weights_only = False,
                            mode='auto',
                            verbose=1)
log['ModelCheckpoint_args'] = ModelCheckpoint_args
checkpoint = ModelCheckpoint(checkpoint_path, **ModelCheckpoint_args)

EarlyStopping_args = dict(monitor='val_jaccard',
                          patience=10,
                          mode='auto',
                          verbose=1)
log['EarlyStopping_args'] = EarlyStopping_args
early = EarlyStopping(**EarlyStopping_args)

# Compile the model
adam = Adam(lr=2.50E-05)
complie_args = dict(optimizer = adam, 
                    loss = dice_log_bce_loss, 
                    metrics = [dice, jaccard, precision, sensitivity, specificity])
log['complie_args'] = complie_args
model_final.compile(**complie_args)

# Set fit_generator
fit_generator_args = dict(steps_per_epoch=len(train_df) // image_parameters['batch_size'],
                          validation_steps=len(valid_df) // image_parameters['batch_size'],
                          epochs=100,
                          initial_epoch = 0,
                          callbacks = [checkpoint, early, reduce_lr, progress_save, progress_plot, csv_logger])
log['fit_generator_args'] = fit_generator_args
save_log(save_dir, log)
history = model_final.fit_generator(train_augmented_generator, validation_data=valid_generator, **fit_generator_args)
# Out:
# ProgressSave: [INFO] Creating file...
# Epoch 1/100
# 520/520 [==============================] - 2049s 4s/step - loss: 0.1969 - dice: 0.8412 - jaccard: 0.7491 - precision: 0.8481 - sensitivity: 0.8778 - specificity: nan - val_loss: 0.1523 - val_dice: 0.8632 - val_jaccard: 0.7750 - val_precision: 0.8468 - val_sensitivity: 0.9121 - val_specificity: 0.9574
#
# Epoch 00001: val_jaccard improved from -inf to 0.77500, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 2/100
# 520/520 [==============================] - 820s 2s/step - loss: 0.1868 - dice: 0.8492 - jaccard: 0.7591 - precision: 0.8594 - sensitivity: 0.8806 - specificity: nan - val_loss: 0.1768 - val_dice: 0.8548 - val_jaccard: 0.7707 - val_precision: 0.8628 - val_sensitivity: 0.8916 - val_specificity: 0.9637
#
# Epoch 00002: val_jaccard did not improve from 0.77500
# Epoch 3/100
# 520/520 [==============================] - 805s 2s/step - loss: 0.2045 - dice: 0.8412 - jaccard: 0.7501 - precision: 0.8511 - sensitivity: 0.8730 - specificity: 0.9643 - val_loss: 0.1679 - val_dice: 0.8554 - val_jaccard: 0.7670 - val_precision: 0.8779 - val_sensitivity: 0.8741 - val_specificity: 0.9731
#
# Epoch 00003: val_jaccard did not improve from 0.77500
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 4/100
# 520/520 [==============================] - 825s 2s/step - loss: 0.1859 - dice: 0.8525 - jaccard: 0.7637 - precision: 0.8537 - sensitivity: 0.8863 - specificity: nan - val_loss: 0.1377 - val_dice: 0.8779 - val_jaccard: 0.7990 - val_precision: 0.8866 - val_sensitivity: 0.9003 - val_specificity: 0.9703
#
# Epoch 00004: val_jaccard improved from 0.77500 to 0.79905, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 5/100
# 520/520 [==============================] - 797s 2s/step - loss: 0.1787 - dice: 0.8561 - jaccard: 0.7685 - precision: 0.8585 - sensitivity: 0.8866 - specificity: 0.9627 - val_loss: 0.1504 - val_dice: 0.8704 - val_jaccard: 0.7895 - val_precision: 0.8873 - val_sensitivity: 0.8923 - val_specificity: 0.9714
#
# Epoch 00005: val_jaccard did not improve from 0.79905
# Epoch 6/100
# 520/520 [==============================] - 811s 2s/step - loss: 0.1763 - dice: 0.8595 - jaccard: 0.7736 - precision: 0.8652 - sensitivity: 0.8843 - specificity: nan - val_loss: 0.1293 - val_dice: 0.8832 - val_jaccard: 0.8064 - val_precision: 0.8945 - val_sensitivity: 0.9005 - val_specificity: 0.9686
#
# Epoch 00006: val_jaccard improved from 0.79905 to 0.80643, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 7/100
# 520/520 [==============================] - 811s 2s/step - loss: 0.1666 - dice: 0.8627 - jaccard: 0.7769 - precision: 0.8665 - sensitivity: 0.8889 - specificity: nan - val_loss: 0.1489 - val_dice: 0.8735 - val_jaccard: 0.7921 - val_precision: 0.9255 - val_sensitivity: 0.8530 - val_specificity: 0.9843
#
# Epoch 00007: val_jaccard did not improve from 0.80643
# Epoch 8/100
# 520/520 [==============================] - 814s 2s/step - loss: 0.1783 - dice: 0.8582 - jaccard: 0.7717 - precision: 0.8604 - sensitivity: 0.8883 - specificity: nan - val_loss: 0.1464 - val_dice: 0.8754 - val_jaccard: 0.7956 - val_precision: 0.9234 - val_sensitivity: 0.8610 - val_specificity: 0.9804
#
# Epoch 00008: val_jaccard did not improve from 0.80643
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 9/100
# 520/520 [==============================] - 807s 2s/step - loss: 0.1723 - dice: 0.8656 - jaccard: 0.7816 - precision: 0.8686 - sensitivity: 0.8891 - specificity: 0.9637 - val_loss: 0.1298 - val_dice: 0.8854 - val_jaccard: 0.8080 - val_precision: 0.9043 - val_sensitivity: 0.8929 - val_specificity: 0.9786
#
# Epoch 00009: val_jaccard improved from 0.80643 to 0.80799, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 10/100
# 520/520 [==============================] - 797s 2s/step - loss: 0.1695 - dice: 0.8685 - jaccard: 0.7858 - precision: 0.8690 - sensitivity: 0.8921 - specificity: 0.9652 - val_loss: 0.1360 - val_dice: 0.8848 - val_jaccard: 0.8091 - val_precision: 0.9179 - val_sensitivity: 0.8807 - val_specificity: 0.9778
#
# Epoch 00010: val_jaccard improved from 0.80799 to 0.80910, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 11/100
# 520/520 [==============================] - 812s 2s/step - loss: 0.1643 - dice: 0.8693 - jaccard: 0.7863 - precision: 0.8710 - sensitivity: 0.8917 - specificity: 0.9643 - val_loss: 0.1284 - val_dice: 0.8848 - val_jaccard: 0.8080 - val_precision: 0.8872 - val_sensitivity: 0.9113 - val_specificity: 0.9704
#
# Epoch 00011: val_jaccard did not improve from 0.80910
# Epoch 12/100
# 520/520 [==============================] - 811s 2s/step - loss: 0.1508 - dice: 0.8749 - jaccard: 0.7929 - precision: 0.8777 - sensitivity: 0.8959 - specificity: nan - val_loss: 0.1224 - val_dice: 0.8895 - val_jaccard: 0.8144 - val_precision: 0.9016 - val_sensitivity: 0.9039 - val_specificity: 0.9748
#
# Epoch 00012: val_jaccard improved from 0.80910 to 0.81441, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 13/100
# 520/520 [==============================] - 810s 2s/step - loss: 0.1523 - dice: 0.8751 - jaccard: 0.7941 - precision: 0.8792 - sensitivity: 0.8943 - specificity: nan - val_loss: 0.1372 - val_dice: 0.8818 - val_jaccard: 0.8039 - val_precision: 0.9120 - val_sensitivity: 0.8808 - val_specificity: 0.9735
#
# Epoch 00013: val_jaccard did not improve from 0.81441
# Epoch 14/100
# 520/520 [==============================] - 819s 2s/step - loss: 0.1627 - dice: 0.8707 - jaccard: 0.7880 - precision: 0.8724 - sensitivity: 0.8923 - specificity: nan - val_loss: 0.1186 - val_dice: 0.8940 - val_jaccard: 0.8201 - val_precision: 0.9176 - val_sensitivity: 0.8946 - val_specificity: 0.9777
#
# Epoch 00014: val_jaccard improved from 0.81441 to 0.82008, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 15/100
# 520/520 [==============================] - 816s 2s/step - loss: 0.1553 - dice: 0.8753 - jaccard: 0.7943 - precision: 0.8779 - sensitivity: 0.8963 - specificity: 0.9632 - val_loss: 0.1238 - val_dice: 0.8928 - val_jaccard: 0.8195 - val_precision: 0.9083 - val_sensitivity: 0.9043 - val_specificity: 0.9770
#
# Epoch 00015: val_jaccard did not improve from 0.82008
# Epoch 16/100
# 520/520 [==============================] - 806s 2s/step - loss: 0.1631 - dice: 0.8698 - jaccard: 0.7878 - precision: 0.8717 - sensitivity: 0.8913 - specificity: nan - val_loss: 0.1386 - val_dice: 0.8838 - val_jaccard: 0.8083 - val_precision: 0.9227 - val_sensitivity: 0.8776 - val_specificity: 0.9782
#
# Epoch 00016: val_jaccard did not improve from 0.82008
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 17/100
# 520/520 [==============================] - 819s 2s/step - loss: 0.1609 - dice: 0.8744 - jaccard: 0.7952 - precision: 0.8769 - sensitivity: 0.8922 - specificity: nan - val_loss: 0.1192 - val_dice: 0.8961 - val_jaccard: 0.8242 - val_precision: 0.9196 - val_sensitivity: 0.8970 - val_specificity: 0.9781
#
# Epoch 00017: val_jaccard improved from 0.82008 to 0.82419, saving model to Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed/data_augmentation_not_freezed_best.hdf5
# Saved predicted images.
# Epoch 18/100
# 520/520 [==============================] - 827s 2s/step - loss: 0.1426 - dice: 0.8808 - jaccard: 0.8013 - precision: 0.8819 - sensitivity: 0.8995 - specificity: 0.9665 - val_loss: 0.1270 - val_dice: 0.8873 - val_jaccard: 0.8125 - val_precision: 0.9031 - val_sensitivity: 0.8992 - val_specificity: 0.9723
#
# Epoch 00018: val_jaccard did not improve from 0.82419
# Epoch 19/100
# 520/520 [==============================] - 813s 2s/step - loss: 0.1490 - dice: 0.8785 - jaccard: 0.7996 - precision: 0.8778 - sensitivity: 0.8993 - specificity: nan - val_loss: 0.1250 - val_dice: 0.8905 - val_jaccard: 0.8154 - val_precision: 0.9196 - val_sensitivity: 0.8889 - val_specificity: 0.9773
#
# Epoch 00019: val_jaccard did not improve from 0.82419
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 20/100
# 520/520 [==============================] - 831s 2s/step - loss: 0.1488 - dice: 0.8790 - jaccard: 0.8003 - precision: 0.8787 - sensitivity: 0.8993 - specificity: 0.9664 - val_loss: 0.1183 - val_dice: 0.8941 - val_jaccard: 0.8209 - val_precision: 0.9121 - val_sensitivity: 0.9001 - val_specificity: 0.9727
#
# Epoch 00020: val_jaccard did not improve from 0.82419
# Epoch 21/100
# 520/520 [==============================] - 820s 2s/step - loss: 0.1446 - dice: 0.8820 - jaccard: 0.8035 - precision: 0.8838 - sensitivity: 0.8988 - specificity: nan - val_loss: 0.1276 - val_dice: 0.8879 - val_jaccard: 0.8129 - val_precision: 0.9060 - val_sensitivity: 0.8977 - val_specificity: 0.9759
#
# Epoch 00021: val_jaccard did not improve from 0.82419
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 22/100
# 520/520 [==============================] - 802s 2s/step - loss: 0.1461 - dice: 0.8825 - jaccard: 0.8045 - precision: 0.8809 - sensitivity: 0.9026 - specificity: 0.9660 - val_loss: 0.1281 - val_dice: 0.8863 - val_jaccard: 0.8116 - val_precision: 0.9129 - val_sensitivity: 0.8896 - val_specificity: 0.9777
#
# Epoch 00022: val_jaccard did not improve from 0.82419
# Epoch 23/100
# 520/520 [==============================] - 820s 2s/step - loss: 0.1401 - dice: 0.8827 - jaccard: 0.8038 - precision: 0.8836 - sensitivity: 0.8998 - specificity: nan - val_loss: 0.1179 - val_dice: 0.8945 - val_jaccard: 0.8210 - val_precision: 0.9114 - val_sensitivity: 0.9012 - val_specificity: 0.9768
#
# Epoch 00023: val_jaccard did not improve from 0.82419
# Epoch 24/100
# 520/520 [==============================] - 801s 2s/step - loss: 0.1513 - dice: 0.8792 - jaccard: 0.8009 - precision: 0.8769 - sensitivity: 0.8997 - specificity: 0.9643 - val_loss: 0.1242 - val_dice: 0.8917 - val_jaccard: 0.8179 - val_precision: 0.9228 - val_sensitivity: 0.8871 - val_specificity: 0.9784
#
# Epoch 00024: val_jaccard did not improve from 0.82419
# Epoch 25/100
# 520/520 [==============================] - 816s 2s/step - loss: 0.1489 - dice: 0.8799 - jaccard: 0.8014 - precision: 0.8797 - sensitivity: 0.8978 - specificity: 0.9666 - val_loss: 0.1274 - val_dice: 0.8902 - val_jaccard: 0.8157 - val_precision: 0.9187 - val_sensitivity: 0.8883 - val_specificity: 0.9729
#
# Epoch 00025: val_jaccard did not improve from 0.82419
# Epoch 26/100
# 520/520 [==============================] - 809s 2s/step - loss: 0.1394 - dice: 0.8842 - jaccard: 0.8059 - precision: 0.8829 - sensitivity: 0.9034 - specificity: 0.9661 - val_loss: 0.1175 - val_dice: 0.8938 - val_jaccard: 0.8197 - val_precision: 0.9059 - val_sensitivity: 0.9054 - val_specificity: 0.9737
#
# Epoch 00026: val_jaccard did not improve from 0.82419
# Epoch 27/100
# 520/520 [==============================] - 823s 2s/step - loss: 0.1392 - dice: 0.8865 - jaccard: 0.8098 - precision: 0.8856 - sensitivity: 0.9031 - specificity: nan - val_loss: 0.1214 - val_dice: 0.8903 - val_jaccard: 0.8160 - val_precision: 0.9031 - val_sensitivity: 0.9045 - val_specificity: 0.9745
#
# Epoch 00027: val_jaccard did not improve from 0.82419
# Epoch 00027: early stopping

# %% [markdown]
# ## Visualize the results

# %%
# load back the best weights
model_final.load_weights('Final_solution/saved_models/Test_Unet_VGG16_classic_data_augmentation_not_freezed' + '/' + "data_augmentation_not_freezed_best.hdf5")

# %%
test_images, test_masks = next(test_generator)
test_predictions = model_final.predict(test_images)

print('Batch size:', test_images.shape[0])
for i in range(test_images.shape[0]):
    print('# in batch:', i+1, ', max, min value: ', test_predictions[i,:,:,:].max(), test_predictions[i,:,:,:].min())
# Out:
# Batch size: 4
# # in batch: 1 , max, min value:  1.0 2.3413526e-05
# # in batch: 2 , max, min value:  1.0 4.533972e-05
# # in batch: 3 , max, min value:  1.0 4.1081923e-05
# # in batch: 4 , max, min value:  1.0 0.0004147419

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (40, 10))

ax1.imshow(montage_rgb(test_images)*0.5+0.5)
ax1.imshow(montage2d(test_predictions[:, :, :, 0]), cmap='gray', alpha=0.3)
ax1.set_title('Image VS prediction');

contours_masks = find_contours(montage2d(test_masks[:, :, :, 0]), level=0.99)
for contour in contours_masks:
  ax1.plot(contour[:, 1], contour[:, 0], "--r", linewidth=0.5)

contours_predictions = find_contours(montage2d(test_predictions[:, :, :, 0]), level=0.9)
for contour in contours_predictions:
  ax1.plot(contour[:, 1], contour[:, 0], "--b", linewidth=0.5)
  
ax2.imshow(montage_rgb(test_images)*0.5+0.5)
ax2.set_title('Original images');
  
ax3.imshow(montage2d(test_predictions[:, :, :, 0]), cmap = 'gray')
ax3.set_title('Predictions');

ax4.imshow(montage2d(test_masks[:, :, :, 0]), cmap = 'gray')
ax4.set_title('Original Masks');

# %% [markdown]
# ## Test the model on test data

# %% [markdown]
# **Get the best model checkpoint files**

# %%
root = 'Final_solution/saved_models'
directory = 'Test_Unet_VGG16_classic_data_augmentation_freezed_V2'
filename = 'data_augmentation_freezed_38_0.157_0.791.hdf5'

save_file_freezed_directory = os.path.join(root, directory)
save_file_freezed_path = os.path.join(save_file_freezed_directory, filename)

root = 'Final_solution/saved_models'
directory = 'Test_Unet_VGG16_classic_data_augmentation_not_freezed'
filename = 'data_augmentation_not_freezed_best.hdf5'

save_file_not_freezed_directory = os.path.join(root, directory)
save_file_not_freezed_path = os.path.join(save_file_not_freezed_directory, filename)

# %% [markdown]
# **Evaluate goal metrics on test data**

# %%
from eval_utils import soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold
from keras.models import load_model
from keras.optimizers import Adam

# %%
model_final = load_model(save_file_not_freezed_path, compile=False)

adam = Adam(lr=0.0001)
model_final.compile(optimizer = adam, 
                    loss = dice_log_bce_loss, 
                    metrics = [soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold])

# %%
results = model_final.evaluate_generator(test_generator, steps=test_df.shape[0] // image_parameters['batch_size'], verbose=1)

for k,v in zip(model_final.metrics_names, results):
    print(k,'%2.4f' % v)
# Out:
# 62/62 [==============================] - 236s 4s/step
# loss 0.1546
# soft_jaccard 0.8117
# soft_jaccard_threshold 0.7623
# hard_jaccard 0.8226
# hard_jaccard_threshold 0.7803

# %% [markdown]
# **Plot the history**

# %%
result_freezed_df = pd.read_csv(os.path.join(save_file_freezed_directory, 'history.csv'))
result_not_freezed_df = pd.read_csv(os.path.join(save_file_not_freezed_directory, 'history.csv'))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = ['val_jaccard', 'val_dice', 'val_precision', 'val_sensitivity', 'val_specificity'], ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = ['val_jaccard', 'val_dice', 'val_precision', 'val_sensitivity', 'val_specificity'], ax=ax2);

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = 'val_loss', ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = 'val_loss', ax=ax2);

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = 'lr', ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = 'lr', ax=ax2);
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Test the loss functions

# %%
from keras.losses import binary_crossentropy
from losses import dice_log_bce_loss
from eval_utils import soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold
from metrics import dice, jaccard, precision, sensitivity, specificity

# %%
test_images, test_masks = next(test_generator)
test_predictions = model_final.predict(test_images)

y_pred = tf.convert_to_tensor(test_predictions, dtype=tf.float32)
y_true = tf.convert_to_tensor(test_masks, dtype=tf.float32)

# %%
import tensorflow as tf
sess = tf.Session()

from keras import backend as K
K.set_session(sess)

# %%
def hard_jaccard_threshold(y_true, y_pred, threshold=0.65, pixel_threshold=0.7):

    y_pred = K.greater(y_pred, pixel_threshold)
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jaccard_index = (intersection / union)
    
    temp = K.greater(jaccard_index, threshold)
    temp = K.cast(temp, 'float32')

    return (temp*jaccard_index), temp, jaccard_index


result = sess.run(hard_jaccard_threshold(y_true, y_pred))

print(result)
# Out:
# (array([0.93733454, 0.8901515 , 0.77291304, 0.9549443 ], dtype=float32), array([1., 1., 1., 1.], dtype=float32), array([0.93733454, 0.8901515 , 0.77291304, 0.9549443 ], dtype=float32))

# %%
def hard_jaccard(y_true, y_pred, pixel_threshold=0.7):

    y_pred = K.greater(y_pred, pixel_threshold)
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jacard_index = (intersection / union)
    
    return jacard_index
  
result = sess.run(hard_jaccard(y_true, y_pred))

print(result)
# Out:
# [0.93733454 0.8901515  0.77291304 0.9549443 ]

# %%
result = sess.run(jaccard(y_true, y_pred))

print(result)
# Out:
# [0.92846084 0.8695071  0.7862567  0.9272945 ]

# %%
def soft_jaccard(y_true, y_pred):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jacard_index = (intersection / union)
    
    return jacard_index

result = sess.run(soft_jaccard(y_true, y_pred))

print(result)
# Out:
# [0.92846084 0.8695071  0.7862567  0.9272945 ]
