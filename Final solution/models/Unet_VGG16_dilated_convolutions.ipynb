# %% [markdown]
# # U-net with VGG16 backbone and dilated convolutions

# %% [markdown]
# **Structure of the used model**
# * U-net like structure with transfer learning:
#   * Encoder: VGG 16 pre-trained on imagenet. Just the first 3 block used.
#   * Botlleneck: Dilated convolutions
#   * Decoder: U-net like, simplified

# %% [markdown]
# <img src="https://ws2.sinaimg.cn/large/006tNbRwgy1fxo4yeljodj30t80fwabp.jpg"
#           align="center"
#           width="800" />

# %% [markdown]
# ## Load general packages. There some more package loading for the more specific tasks

# %%
colab = True

# %%
# for file handling
import os
from pathlib import Path

# Only if working from Google Colab
if colab:
    # Mount the Google Drive to reach its data
    from google.colab import drive
    drive.mount('/content/gdrive')
    os.chdir('/content/gdrive/My Drive')
    # making sure we used the newest versions
    # !pip install --upgrade keras 
    # !pip install --upgrade tensorflow

import sys
sys.path.append('Final_solution')    

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# for numeric calculations
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

# for data handling
import pandas as pd

# for plotting the preprocessed images and the output images and masks
from skimage.measure import find_contours
from skimage.util.montage import montage2d
montage_rgb = lambda x: np.stack([montage2d(x[:, :, :, i]) for i in range(x.shape[3])], -1)

# %% [markdown]
# **log dictionary is used to make a log file after every parameters is collected**

# %%
log = {}

# %% [markdown]
# ## Data handling and preprocessing

# %%
from data_utils import load_paths, make_split, make_generators
from keras.applications.vgg16 import preprocess_input
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Define the image parameters and the batch size**

# %%
image_parameters = dict(batch_size = 4,
                        image_size = (512, 512))
image_parameters['input_shape'] = image_parameters['image_size'] + (3,)

log['image_parameters'] = image_parameters

# %%
data_df = load_paths(root='ISIC2018')
train_df, valid_df, test_df = make_split(data_df, train_size=2080, valid_size=264)

print('images:', len(data_df),'train images:', len(train_df), 'valid images:', len(valid_df),'test images:', len(test_df))
data_df.head()
# Out:
# images: 2594 train images: 2080 valid images: 264 test images: 250
#                                              image_path      image_id  \
# 2001  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000000
# 1998  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000001
# 1999  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000003
# 2004  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000004
# 2003  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000006
#
#         image_filename                                         task1_path  \
# 2001  ISIC_0000000.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 1998  ISIC_0000001.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 1999  ISIC_0000003.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 2004  ISIC_0000004.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 2003  ISIC_0000006.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
#
#                      task1_filename
# 2001  ISIC_0000000_segmentation.png
# 1998  ISIC_0000001_segmentation.png
# 1999  ISIC_0000003_segmentation.png
# 2004  ISIC_0000004_segmentation.png
# 2003  ISIC_0000006_segmentation.png

# %%
# Set the ImageDataGenerator arguments in a dictionary
data_gen_args = dict(data_format = 'channels_last',
                     preprocessing_function = lambda x: preprocess_input(x, data_format='channels_last', mode='tf'))
log['ImageDataGenerator_image_args'] = data_gen_args

# Use the same for the masks and images. (We use same seed value too.)
mask_gen_args = data_gen_args.copy()
mask_gen_args['preprocessing_function'] = lambda x: x/255.0
log['ImageDataGenerator_mask_args'] = mask_gen_args

# %%
# set the flow_from_directory arguments in a dictionary
image_flow_from_dataframe_args = dict(seed = 999,
                                      class_mode=None,
                                      batch_size=image_parameters['batch_size'],
                                      x_col='image_filename',
                                      color_mode = 'rgb',
                                      target_size = image_parameters['image_size'])
log['FlowFromDataframe_image_args'] = image_flow_from_dataframe_args

# use the same arguments for the masks and images. (We use same seed value too.)
mask_flow_from_dataframe_args = image_flow_from_dataframe_args.copy()
mask_flow_from_dataframe_args['x_col'] = 'task1_filename'
mask_flow_from_dataframe_args['color_mode'] = 'grayscale'
log['FlowFromDataframe_mask_args'] = mask_flow_from_dataframe_args

# %%
train_generator, valid_generator, test_generator = make_generators(data_gen_args, mask_gen_args, image_flow_from_dataframe_args, mask_flow_from_dataframe_args, train_df, valid_df, test_df)
# Out:
# Found 2080 images.
# Found 2080 images.
# Found 264 images.
# Found 264 images.
# Found 250 images.
# Found 250 images.

# %%
probe_image, probe_mask = next(test_generator)

print('image', probe_image.shape, probe_image.dtype, probe_image.min(), probe_image.max())
print('mask', probe_mask.shape, probe_mask.dtype, probe_mask.min(), probe_mask.max())

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (20, 10))

ax1.imshow(montage_rgb(probe_image)*0.5+0.5)
ax1.imshow(montage2d(probe_mask[:, :, :, 0]), cmap='gray',alpha=0.3)
ax1.set_title('Images VS Masks')

ax2.imshow(montage_rgb(probe_image)*0.5+0.5)
ax2.set_title('Images')

ax3.imshow(montage2d(probe_mask[:, :, :, 0]), cmap='gray')
ax3.set_title('Masks')

plt.show()
# Out:
# image (4, 512, 512, 3) float32 -1.0 1.0
# mask (4, 512, 512, 1) float32 0.0 1.0

# %% [markdown]
# ## Build the model

# %% [markdown]
# **import the necessary packages**

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, Activation, MaxPooling2D, Concatenate, UpSampling2D, BatchNormalization, Dropout, Add

from keras.applications.vgg16 import VGG16

from model_utils import get_layer_size_dict, concat_layers_dict, save_log

# %% [markdown]
# **Loading the pretrained VGG16 network. This is our encoder part.**

# %%
VGG16_args = dict(input_shape = image_parameters['input_shape'], 
                  include_top = False, 
                  weights = 'imagenet')
log['VGG16_args'] = VGG16_args

vgg16 = VGG16(**VGG16_args)
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 2s 0us/step

# %% [markdown]
# **Collect the layer sizes for the decoder part, inspect the structue of the pre-trained model**

# %%
layer_size_dict = get_layer_size_dict(vgg16)

for shape, layer_names in zip(layer_size_dict.keys(), layer_size_dict.values()):
    print('Otuput shape:', shape, 'Layer names:', [temp.name for temp in layer_names])
# Out:
# Otuput shape: (512, 512) Layer names: ['input_1', 'block1_conv1', 'block1_conv2']
# Otuput shape: (256, 256) Layer names: ['block1_pool', 'block2_conv1', 'block2_conv2']
# Otuput shape: (128, 128) Layer names: ['block2_pool', 'block3_conv1', 'block3_conv2', 'block3_conv3']
# Otuput shape: (64, 64) Layer names: ['block3_pool', 'block4_conv1', 'block4_conv2', 'block4_conv3']
# Otuput shape: (32, 32) Layer names: ['block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3']
# Otuput shape: (16, 16) Layer names: ['block5_pool']

# %%
concat_layers = concat_layers_dict(layer_size_dict)

for shape, output in zip(concat_layers.keys(), concat_layers.values()):
    print('Output shape: ', shape, 'Last output: ', output)
# Out:
# Output shape:  (512, 512) Last output:  Tensor("block1_conv2/Relu:0", shape=(?, 512, 512, 64), dtype=float32)
# Output shape:  (256, 256) Last output:  Tensor("block2_conv2/Relu:0", shape=(?, 256, 256, 128), dtype=float32)
# Output shape:  (128, 128) Last output:  Tensor("block3_conv3/Relu:0", shape=(?, 128, 128, 256), dtype=float32)
# Output shape:  (64, 64) Last output:  Tensor("block4_conv3/Relu:0", shape=(?, 64, 64, 512), dtype=float32)
# Output shape:  (32, 32) Last output:  Tensor("block5_conv3/Relu:0", shape=(?, 32, 32, 512), dtype=float32)
# Output shape:  (16, 16) Last output:  Tensor("block5_pool/MaxPool:0", shape=(?, 16, 16, 512), dtype=float32)

# %% [markdown]
# **Build the decoder part**

# %%
encoder_output = vgg16.get_layer('block3_pool').output

# Bottle neck
##########################################################################

dilated_layers = []

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal')(encoder_output)
x = BatchNormalization()(x)
x = Activation('elu')(x)
dilated_layers.append(x)

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal', dilation_rate = 2)(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
dilated_layers.append(x)

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal', dilation_rate = 4)(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
dilated_layers.append(x)

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal', dilation_rate = 8)(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)
dilated_layers.append(x)

decoder_input = Add()(dilated_layers)

# Decoder
##########################################################################

x = UpSampling2D(size=(2,2))(decoder_input)
x = Conv2D(256, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(256, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Conv2D(128, (3, 3), padding='same')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(128, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Conv2D(64, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(64, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = Conv2D(32, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

x = Conv2D(1, (1, 1), padding='same', kernel_initializer ='he_normal')(x)
model_output = Activation('sigmoid')(x)

model_final = Model(inputs=vgg16.input, outputs=model_output)

# %%
model_final.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 512, 512, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 512, 512, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 256, 256, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 256, 256, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 256, 256, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 128, 128, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 128, 128, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 128, 128, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 128, 128, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 64, 64, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 512)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 512)  2359808     activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 512)  2359808     activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 512)  2359808     activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 512)  2048        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 512)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 512)  0           activation_1[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 512 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 256 1179904     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 512 0           conv2d_5[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 256 1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 256 1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 256 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 256 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 128 295040      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 256 0           conv2d_7[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256, 256, 128 512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 256, 256, 128 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 128 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 512, 512, 64) 73792       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 128 0           conv2d_9[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 512, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512, 512, 64) 256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 512, 512, 64) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 512, 32) 18464       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 512, 512, 32) 128         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 512, 512, 32) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 512, 512, 1)  33          activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512, 512, 1)  0           conv2d_12[0][0]
# ==================================================================================================
# Total params: 13,121,153
# Trainable params: 13,116,097
# Non-trainable params: 5,056
# __________________________________________________________________________________________________

# %%
from losses import dice_log_bce_loss
from keras.losses import binary_crossentropy

from metrics import dice, jaccard, precision, sensitivity, specificity

from callbacks import ProgeressPlot, ProgressSave
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau, Callback, CSVLogger, CallbackList

from keras.optimizers import SGD, Adam, Nadam

# %%
save_dir = 'Final_solution/saved_models' + '/' + 'Unet_VGG16_dilated_convolutions_not_freezed'

# Set which layers can learn
for layer in vgg16.layers[1:]:
    layer.trainable = True

# Set callbacks
progress_save = ProgressSave(file_mode='w', save_dir=save_dir, filename='history.csv')

progress_plot = ProgeressPlot(next(test_generator), monitor='val_jaccard', save_dir=save_dir)

ReduceLROnPlateau_args = dict(monitor='val_jaccard',
                              mode='auto',
                              patience=2,
                              factor=0.5,
                              min_lr=0.000001,
                              verbose=1)
log['ReduceLROnPlateau_args'] = ReduceLROnPlateau_args
reduce_lr = ReduceLROnPlateau(**ReduceLROnPlateau_args)

checkpoint_path = save_dir + '/' + 'not_freezed' + '_{epoch:02d}_{val_loss:.3f}_{val_jaccard:.3f}.hdf5'
ModelCheckpoint_args = dict(monitor='val_jaccard',
                            save_best_only=True,  
                            save_weights_only = False,
                            mode='auto',
                            verbose=1)
log['ModelCheckpoint_args'] = ModelCheckpoint_args
checkpoint = ModelCheckpoint(checkpoint_path, **ModelCheckpoint_args)

EarlyStopping_args = dict(monitor='val_jaccard',
                          patience=10,
                          mode='auto',
                          verbose=1)
log['EarlyStopping_args'] = EarlyStopping_args
early = EarlyStopping(**EarlyStopping_args)

# Compile the model
adam = Adam(lr=0.0001)
complie_args = dict(optimizer = adam, 
                    loss = dice_log_bce_loss, 
                    metrics = [dice, jaccard, precision, sensitivity, specificity])
log['complie_args'] = complie_args
model_final.compile(**complie_args)

# Set fit_generator
fit_generator_args = dict(steps_per_epoch=len(train_df) // image_parameters['batch_size'],
                          validation_steps=len(valid_df) // image_parameters['batch_size'],
                          epochs=50,
                          initial_epoch = 0,
                          callbacks = [checkpoint, early, reduce_lr, progress_save, progress_plot])
log['fit_generator_args'] = fit_generator_args
save_log(save_dir, log)
history = model_final.fit_generator(train_generator, validation_data=valid_generator, **fit_generator_args)
# Out:
# ProgressSave: [INFO] Creating file...
# Epoch 1/50
# 520/520 [==============================] - 2143s 4s/step - loss: 0.2220 - dice: 0.8272 - jaccard: 0.7314 - precision: 0.8472 - sensitivity: 0.8644 - specificity: 0.9674 - val_loss: 0.6109 - val_dice: 0.5899 - val_jaccard: 0.4703 - val_precision: 0.5042 - val_sensitivity: 0.9357 - val_specificity: 0.8116
#
# Epoch 00001: val_jaccard improved from -inf to 0.47029, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_01_0.611_0.470.hdf5
# Saved predicted images.
# Epoch 2/50
# 520/520 [==============================] - 1267s 2s/step - loss: 0.2173 - dice: 0.8288 - jaccard: 0.7332 - precision: 0.8454 - sensitivity: 0.8676 - specificity: 0.9681 - val_loss: 0.5532 - val_dice: 0.5940 - val_jaccard: 0.4678 - val_precision: 0.5269 - val_sensitivity: 0.8656 - val_specificity: 0.8465
#
# Epoch 00002: val_jaccard did not improve from 0.47029
# Epoch 3/50
# 520/520 [==============================] - 1261s 2s/step - loss: 0.2098 - dice: 0.8333 - jaccard: 0.7382 - precision: 0.8522 - sensitivity: 0.8675 - specificity: 0.9696 - val_loss: 0.3182 - val_dice: 0.7552 - val_jaccard: 0.6493 - val_precision: 0.7227 - val_sensitivity: 0.9011 - val_specificity: 0.9261
#
# Epoch 00003: val_jaccard improved from 0.47029 to 0.64930, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_03_0.318_0.649.hdf5
# Saved predicted images.
# Epoch 4/50
# 520/520 [==============================] - 1266s 2s/step - loss: 0.1832 - dice: 0.8509 - jaccard: 0.7612 - precision: 0.8671 - sensitivity: 0.8788 - specificity: 0.9697 - val_loss: 0.2635 - val_dice: 0.7855 - val_jaccard: 0.6752 - val_precision: 0.7313 - val_sensitivity: 0.9224 - val_specificity: 0.9263
#
# Epoch 00004: val_jaccard improved from 0.64930 to 0.67518, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_04_0.263_0.675.hdf5
# Saved predicted images.
# Epoch 5/50
# 520/520 [==============================] - 1259s 2s/step - loss: 0.1837 - dice: 0.8495 - jaccard: 0.7593 - precision: 0.8649 - sensitivity: 0.8788 - specificity: 0.9697 - val_loss: 0.3237 - val_dice: 0.8066 - val_jaccard: 0.7199 - val_precision: 0.9108 - val_sensitivity: 0.7737 - val_specificity: 0.9875
#
# Epoch 00005: val_jaccard improved from 0.67518 to 0.71995, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_05_0.324_0.720.hdf5
# Saved predicted images.
# Epoch 6/50
# 520/520 [==============================] - 1262s 2s/step - loss: 0.1828 - dice: 0.8515 - jaccard: 0.7618 - precision: 0.8673 - sensitivity: 0.8799 - specificity: 0.9697 - val_loss: 0.2698 - val_dice: 0.7763 - val_jaccard: 0.6710 - val_precision: 0.7286 - val_sensitivity: 0.9165 - val_specificity: 0.9250
#
# Epoch 00006: val_jaccard did not improve from 0.71995
# Epoch 7/50
# 520/520 [==============================] - 1263s 2s/step - loss: 0.1843 - dice: 0.8499 - jaccard: 0.7595 - precision: 0.8643 - sensitivity: 0.8800 - specificity: 0.9693 - val_loss: 0.2501 - val_dice: 0.8214 - val_jaccard: 0.7271 - val_precision: 0.8447 - val_sensitivity: 0.8561 - val_specificity: 0.9746
#
# Epoch 00007: val_jaccard improved from 0.71995 to 0.72712, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_07_0.250_0.727.hdf5
# Saved predicted images.
# Epoch 8/50
# 520/520 [==============================] - 1259s 2s/step - loss: 0.1753 - dice: 0.8561 - jaccard: 0.7681 - precision: 0.8709 - sensitivity: 0.8834 - specificity: 0.9699 - val_loss: 0.2020 - val_dice: 0.8329 - val_jaccard: 0.7407 - val_precision: 0.8689 - val_sensitivity: 0.8437 - val_specificity: 0.9718
#
# Epoch 00008: val_jaccard improved from 0.72712 to 0.74068, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_08_0.202_0.741.hdf5
# Saved predicted images.
# Epoch 9/50
# 520/520 [==============================] - 1261s 2s/step - loss: 0.1700 - dice: 0.8591 - jaccard: 0.7715 - precision: 0.8734 - sensitivity: 0.8846 - specificity: 0.9704 - val_loss: 0.2145 - val_dice: 0.8440 - val_jaccard: 0.7593 - val_precision: 0.9014 - val_sensitivity: 0.8284 - val_specificity: 0.9810
#
# Epoch 00009: val_jaccard improved from 0.74068 to 0.75928, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_09_0.215_0.759.hdf5
# Saved predicted images.
# Epoch 10/50
# 520/520 [==============================] - 1264s 2s/step - loss: 0.1715 - dice: 0.8564 - jaccard: 0.7677 - precision: 0.8691 - sensitivity: 0.8840 - specificity: 0.9699 - val_loss: 0.3177 - val_dice: 0.7622 - val_jaccard: 0.6609 - val_precision: 0.7074 - val_sensitivity: 0.9295 - val_specificity: 0.9016
#
# Epoch 00010: val_jaccard did not improve from 0.75928
# Epoch 11/50
# 520/520 [==============================] - 1267s 2s/step - loss: 0.1668 - dice: 0.8619 - jaccard: 0.7755 - precision: 0.8762 - sensitivity: 0.8867 - specificity: 0.9713 - val_loss: 0.4649 - val_dice: 0.6814 - val_jaccard: 0.5737 - val_precision: 0.6055 - val_sensitivity: 0.9467 - val_specificity: 0.8515
#
# Epoch 00011: val_jaccard did not improve from 0.75928
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 12/50
# 520/520 [==============================] - 1261s 2s/step - loss: 0.1396 - dice: 0.8794 - jaccard: 0.7987 - precision: 0.8922 - sensitivity: 0.8963 - specificity: 0.9714 - val_loss: 0.2032 - val_dice: 0.8542 - val_jaccard: 0.7738 - val_precision: 0.9205 - val_sensitivity: 0.8350 - val_specificity: 0.9865
#
# Epoch 00012: val_jaccard improved from 0.75928 to 0.77382, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_12_0.203_0.774.hdf5
# Saved predicted images.
# Epoch 13/50
# 520/520 [==============================] - 1263s 2s/step - loss: 0.1289 - dice: 0.8877 - jaccard: 0.8095 - precision: 0.8985 - sensitivity: 0.9012 - specificity: 0.9723 - val_loss: 0.1752 - val_dice: 0.8646 - val_jaccard: 0.7866 - val_precision: 0.9079 - val_sensitivity: 0.8618 - val_specificity: 0.9790
#
# Epoch 00013: val_jaccard improved from 0.77382 to 0.78665, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_13_0.175_0.787.hdf5
# Saved predicted images.
# Epoch 14/50
# 520/520 [==============================] - 1267s 2s/step - loss: 0.1274 - dice: 0.8884 - jaccard: 0.8107 - precision: 0.8996 - sensitivity: 0.9019 - specificity: 0.9722 - val_loss: 0.1664 - val_dice: 0.8637 - val_jaccard: 0.7825 - val_precision: 0.8939 - val_sensitivity: 0.8732 - val_specificity: 0.9806
#
# Epoch 00014: val_jaccard did not improve from 0.78665
# Epoch 15/50
# 520/520 [==============================] - 1260s 2s/step - loss: 0.1271 - dice: 0.8886 - jaccard: 0.8109 - precision: 0.8988 - sensitivity: 0.9029 - specificity: 0.9724 - val_loss: 0.1853 - val_dice: 0.8438 - val_jaccard: 0.7569 - val_precision: 0.8358 - val_sensitivity: 0.9009 - val_specificity: 0.9536
#
# Epoch 00015: val_jaccard did not improve from 0.78665
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 16/50
# 520/520 [==============================] - 1267s 2s/step - loss: 0.1142 - dice: 0.8984 - jaccard: 0.8247 - precision: 0.9063 - sensitivity: 0.9104 - specificity: 0.9730 - val_loss: 0.1941 - val_dice: 0.8623 - val_jaccard: 0.7860 - val_precision: 0.8991 - val_sensitivity: 0.8693 - val_specificity: 0.9783
#
# Epoch 00016: val_jaccard did not improve from 0.78665
# Epoch 17/50
# 520/520 [==============================] - 1267s 2s/step - loss: 0.1089 - dice: 0.9028 - jaccard: 0.8308 - precision: 0.9101 - sensitivity: 0.9130 - specificity: 0.9731 - val_loss: 0.1663 - val_dice: 0.8665 - val_jaccard: 0.7886 - val_precision: 0.8940 - val_sensitivity: 0.8779 - val_specificity: 0.9730
#
# Epoch 00017: val_jaccard improved from 0.78665 to 0.78857, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_17_0.166_0.789.hdf5
# Saved predicted images.
# Epoch 18/50
# 520/520 [==============================] - 1265s 2s/step - loss: 0.1079 - dice: 0.9034 - jaccard: 0.8316 - precision: 0.9116 - sensitivity: 0.9123 - specificity: 0.9733 - val_loss: 0.1885 - val_dice: 0.8610 - val_jaccard: 0.7832 - val_precision: 0.9094 - val_sensitivity: 0.8570 - val_specificity: 0.9805
#
# Epoch 00018: val_jaccard did not improve from 0.78857
# Epoch 19/50
# 520/520 [==============================] - 1263s 2s/step - loss: 0.1039 - dice: 0.9060 - jaccard: 0.8351 - precision: 0.9120 - sensitivity: 0.9156 - specificity: 0.9732 - val_loss: 0.1876 - val_dice: 0.8644 - val_jaccard: 0.7872 - val_precision: 0.8917 - val_sensitivity: 0.8781 - val_specificity: 0.9740
#
# Epoch 00019: val_jaccard did not improve from 0.78857
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 20/50
# 520/520 [==============================] - 1268s 2s/step - loss: 0.0981 - dice: 0.9115 - jaccard: 0.8436 - precision: 0.9175 - sensitivity: 0.9194 - specificity: 0.9739 - val_loss: 0.1815 - val_dice: 0.8604 - val_jaccard: 0.7811 - val_precision: 0.9107 - val_sensitivity: 0.8520 - val_specificity: 0.9804
#
# Epoch 00020: val_jaccard did not improve from 0.78857
# Epoch 21/50
# 520/520 [==============================] - 1260s 2s/step - loss: 0.0965 - dice: 0.9123 - jaccard: 0.8445 - precision: 0.9176 - sensitivity: 0.9200 - specificity: 0.9739 - val_loss: 0.1686 - val_dice: 0.8662 - val_jaccard: 0.7879 - val_precision: 0.8848 - val_sensitivity: 0.8867 - val_specificity: 0.9710
#
# Epoch 00021: val_jaccard did not improve from 0.78857
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 22/50
# 520/520 [==============================] - 1263s 2s/step - loss: 0.0925 - dice: 0.9147 - jaccard: 0.8484 - precision: 0.9194 - sensitivity: 0.9226 - specificity: 0.9750 - val_loss: 0.1712 - val_dice: 0.8655 - val_jaccard: 0.7882 - val_precision: 0.8952 - val_sensitivity: 0.8746 - val_specificity: 0.9748
#
# Epoch 00022: val_jaccard did not improve from 0.78857
# Epoch 23/50
# 520/520 [==============================] - 1266s 2s/step - loss: 0.0905 - dice: 0.9167 - jaccard: 0.8511 - precision: 0.9208 - sensitivity: 0.9238 - specificity: 0.9745 - val_loss: 0.1779 - val_dice: 0.8643 - val_jaccard: 0.7873 - val_precision: 0.8908 - val_sensitivity: 0.8781 - val_specificity: 0.9729
#
# Epoch 00023: val_jaccard did not improve from 0.78857
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 24/50
# 520/520 [==============================] - 1264s 2s/step - loss: 0.0883 - dice: 0.9187 - jaccard: 0.8544 - precision: 0.9227 - sensitivity: 0.9253 - specificity: 0.9752 - val_loss: 0.1792 - val_dice: 0.8658 - val_jaccard: 0.7902 - val_precision: 0.9068 - val_sensitivity: 0.8651 - val_specificity: 0.9800
#
# Epoch 00024: val_jaccard improved from 0.78857 to 0.79015, saving model to Final_solution/saved_models/Unet_VGG16_dilated_convolutions_not_freezed/not_freezed_24_0.179_0.790.hdf5
# Saved predicted images.
# Epoch 25/50
# 520/520 [==============================] - 1271s 2s/step - loss: 0.0884 - dice: 0.9187 - jaccard: 0.8544 - precision: 0.9231 - sensitivity: 0.9251 - specificity: 0.9754 - val_loss: 0.1778 - val_dice: 0.8641 - val_jaccard: 0.7873 - val_precision: 0.9045 - val_sensitivity: 0.8643 - val_specificity: 0.9799
#
# Epoch 00025: val_jaccard did not improve from 0.79015
# Epoch 26/50
# 520/520 [==============================] - 1268s 2s/step - loss: 0.0869 - dice: 0.9193 - jaccard: 0.8551 - precision: 0.9235 - sensitivity: 0.9253 - specificity: 0.9747 - val_loss: 0.1763 - val_dice: 0.8659 - val_jaccard: 0.7893 - val_precision: 0.8975 - val_sensitivity: 0.8739 - val_specificity: 0.9777
#
# Epoch 00026: val_jaccard did not improve from 0.79015
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 27/50
# 520/520 [==============================] - 1265s 2s/step - loss: 0.0860 - dice: 0.9203 - jaccard: 0.8568 - precision: 0.9247 - sensitivity: 0.9259 - specificity: 0.9755 - val_loss: 0.1789 - val_dice: 0.8651 - val_jaccard: 0.7887 - val_precision: 0.9002 - val_sensitivity: 0.8701 - val_specificity: 0.9780
#
# Epoch 00027: val_jaccard did not improve from 0.79015
# Epoch 28/50
# 520/520 [==============================] - 1269s 2s/step - loss: 0.0864 - dice: 0.9198 - jaccard: 0.8560 - precision: 0.9234 - sensitivity: 0.9264 - specificity: 0.9752 - val_loss: 0.1825 - val_dice: 0.8645 - val_jaccard: 0.7885 - val_precision: 0.9056 - val_sensitivity: 0.8637 - val_specificity: 0.9789
#
# Epoch 00028: val_jaccard did not improve from 0.79015
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 29/50
# 520/520 [==============================] - 1267s 2s/step - loss: 0.0853 - dice: 0.9210 - jaccard: 0.8578 - precision: 0.9254 - sensitivity: 0.9263 - specificity: 0.9751 - val_loss: 0.1771 - val_dice: 0.8654 - val_jaccard: 0.7888 - val_precision: 0.8990 - val_sensitivity: 0.8708 - val_specificity: 0.9771
#
# Epoch 00029: val_jaccard did not improve from 0.79015
# Epoch 30/50
# 520/520 [==============================] - 1262s 2s/step - loss: 0.0854 - dice: 0.9208 - jaccard: 0.8577 - precision: 0.9251 - sensitivity: 0.9265 - specificity: 0.9754 - val_loss: 0.1795 - val_dice: 0.8648 - val_jaccard: 0.7885 - val_precision: 0.8986 - val_sensitivity: 0.8705 - val_specificity: 0.9767
#
# Epoch 00030: val_jaccard did not improve from 0.79015
# Epoch 31/50
# 520/520 [==============================] - 1264s 2s/step - loss: 0.0858 - dice: 0.9207 - jaccard: 0.8573 - precision: 0.9239 - sensitivity: 0.9273 - specificity: 0.9745 - val_loss: 0.1790 - val_dice: 0.8655 - val_jaccard: 0.7894 - val_precision: 0.9014 - val_sensitivity: 0.8692 - val_specificity: 0.9777
#
# Epoch 00031: val_jaccard did not improve from 0.79015
# Epoch 32/50
# 520/520 [==============================] - 1266s 2s/step - loss: 0.0863 - dice: 0.9209 - jaccard: 0.8577 - precision: 0.9256 - sensitivity: 0.9261 - specificity: 0.9759 - val_loss: 0.1797 - val_dice: 0.8646 - val_jaccard: 0.7884 - val_precision: 0.9034 - val_sensitivity: 0.8663 - val_specificity: 0.9788
#
# Epoch 00032: val_jaccard did not improve from 0.79015
# Epoch 33/50
# 520/520 [==============================] - 1269s 2s/step - loss: 0.0849 - dice: 0.9213 - jaccard: 0.8583 - precision: 0.9252 - sensitivity: 0.9271 - specificity: 0.9751 - val_loss: 0.1825 - val_dice: 0.8643 - val_jaccard: 0.7882 - val_precision: 0.9040 - val_sensitivity: 0.8655 - val_specificity: 0.9788
#
# Epoch 00033: val_jaccard did not improve from 0.79015
# Epoch 34/50
# 110/520 [=====>........................] - ETA: 15:31 - loss: 0.0842 - dice: 0.9226 - jaccard: 0.8605 - precision: 0.9263 - sensitivity: 0.9281 - specificity: 0.9757

# %% [markdown]
# ## Visualize the results

# %%
# load back the best weights
model_final.load_weights('Final_solution/saved_models/Unet_VGG16_dilated_convolutions_freezed' + '/' + "freezed_26_0.194_0.778.hdf5")

# %%
test_images, test_masks = next(test_generator)
test_predictions = model_final.predict(test_images)

print('Batch size:', test_images.shape[0])
for i in range(test_images.shape[0]):
    print('# in batch:', i+1, ', max, min value: ', test_predictions[i,:,:,:].max(), test_predictions[i,:,:,:].min())
# Out:
# Batch size: 4
# # in batch: 1 , max, min value:  1.0 1.14958674e-07
# # in batch: 2 , max, min value:  1.0 6.110436e-07
# # in batch: 3 , max, min value:  1.0 2.859063e-06
# # in batch: 4 , max, min value:  1.0 4.443358e-06

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (40, 10))

ax1.imshow(montage_rgb(test_images)*0.5+0.5)
ax1.imshow(montage2d(test_predictions[:, :, :, 0]), cmap='gray', alpha=0.3)
ax1.set_title('Image VS prediction');

contours_masks = find_contours(montage2d(test_masks[:, :, :, 0]), level=0.99)
for contour in contours_masks:
  ax1.plot(contour[:, 1], contour[:, 0], "--r", linewidth=0.5)

contours_predictions = find_contours(montage2d(test_predictions[:, :, :, 0]), level=0.9)
for contour in contours_predictions:
  ax1.plot(contour[:, 1], contour[:, 0], "--b", linewidth=0.5)
  
ax2.imshow(montage_rgb(test_images)*0.5+0.5)
ax2.set_title('Original images');
  
ax3.imshow(montage2d(test_predictions[:, :, :, 0]), cmap = 'gray')
ax3.set_title('Predictions');

ax4.imshow(montage2d(test_masks[:, :, :, 0]), cmap = 'gray')
ax4.set_title('Original Masks');
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Test the model on test data

# %% [markdown]
# **Get the best model checkpoint files**

# %%
root = 'Final_solution/saved_models'
directory = 'Unet_VGG16_dilated_convolutions_freezed'
filename = 'freezed_26_0.194_0.778.hdf5'

save_file_freezed_directory = os.path.join(root, directory)
save_file_freezed_path = os.path.join(save_file_freezed_directory, filename)

root = 'Final_solution/saved_models'
directory = 'Unet_VGG16_dilated_convolutions_not_freezed'
filename = 'not_freezed_24_0.179_0.790.hdf5'

save_file_not_freezed_directory = os.path.join(root, directory)
save_file_not_freezed_path = os.path.join(save_file_not_freezed_directory, filename)

# %% [markdown]
# **Evaluate goal metrics on test data**

# %%
from eval_utils import soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold
from keras.models import load_model
from keras.optimizers import Adam

# %%
model_final = load_model(save_file_not_freezed_path, compile=False)

adam = Adam(lr=0.0001)
model_final.compile(optimizer = adam, 
                    loss = dice_log_bce_loss, 
                    metrics = [soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold])

# %%
results = model_final.evaluate_generator(test_generator, steps=test_df.shape[0] // image_parameters['batch_size'], verbose=1)

for k,v in zip(model_final.metrics_names, results):
    print(k,'%2.4f' % v)
# Out:
# 62/62 [==============================] - 245s 4s/step
# loss 0.1703
# soft_jaccard 0.7981
# soft_jaccard_threshold 0.7239
# hard_jaccard 0.8073
# hard_jaccard_threshold 0.7305

# %% [markdown]
# **Plot the history**

# %%
result_freezed_df = pd.read_csv(os.path.join(save_file_freezed_directory, 'history.csv'))
result_not_freezed_df = pd.read_csv(os.path.join(save_file_not_freezed_directory, 'history.csv'))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = ['val_jaccard', 'val_dice', 'val_precision', 'val_sensitivity', 'val_specificity'], ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = ['val_jaccard', 'val_dice', 'val_precision', 'val_sensitivity', 'val_specificity'], ax=ax2);

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = 'val_loss', ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = 'val_loss', ax=ax2);

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = 'lr', ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = 'lr', ax=ax2);
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Test the loss functions

# %%
from keras.losses import binary_crossentropy
from losses import dice_log_bce_loss
from eval_utils import soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold
from metrics import dice, jaccard, precision, sensitivity, specificity

# %%
test_images, test_masks = next(test_generator)
test_predictions = model_final.predict(test_images)

y_pred = tf.convert_to_tensor(test_predictions, dtype=tf.float32)
y_true = tf.convert_to_tensor(test_masks, dtype=tf.float32)

# %%
import tensorflow as tf
sess = tf.Session()

from keras import backend as K
K.set_session(sess)

# %%
def hard_jaccard_threshold(y_true, y_pred, threshold=0.65, pixel_threshold=0.7):

    y_pred = K.greater(y_pred, pixel_threshold)
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jaccard_index = (intersection / union)
    
    temp = K.greater(jaccard_index, threshold)
    temp = K.cast(temp, 'float32')

    return (temp*jaccard_index), temp, jaccard_index


result = sess.run(hard_jaccard_threshold(y_true, y_pred))

print(result)
# Out:
# (array([0.93733454, 0.8901515 , 0.77291304, 0.9549443 ], dtype=float32), array([1., 1., 1., 1.], dtype=float32), array([0.93733454, 0.8901515 , 0.77291304, 0.9549443 ], dtype=float32))

# %%
def hard_jaccard(y_true, y_pred, pixel_threshold=0.7):

    y_pred = K.greater(y_pred, pixel_threshold)
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jacard_index = (intersection / union)
    
    return jacard_index
  
result = sess.run(hard_jaccard(y_true, y_pred))

print(result)
# Out:
# [0.93733454 0.8901515  0.77291304 0.9549443 ]

# %%
result = sess.run(jaccard(y_true, y_pred))

print(result)
# Out:
# [0.92846084 0.8695071  0.7862567  0.9272945 ]

# %%
def soft_jaccard(y_true, y_pred):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jacard_index = (intersection / union)
    
    return jacard_index

result = sess.run(soft_jaccard(y_true, y_pred))

print(result)
# Out:
# [0.92846084 0.8695071  0.7862567  0.9272945 ]
