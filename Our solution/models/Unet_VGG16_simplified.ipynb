# %% [markdown]
# # Simplified U-net with VGG16 backbone

# %% [markdown]
# **Structure of the used model**
# * U-net like structure with transfer learning:
#   * Encoder: VGG 16 pre-trained on imagenet.
#   * Bottleneck: just one convolution
#   * Decoder: U-net like, simplified

# %% [markdown]
# <img src="https://ws1.sinaimg.cn/large/006tNbRwgy1fxrgnley3jj310c0iljtd.jpg"
#           align="center"
#           width="800" />

# %% [markdown]
# ## Load general packages. There some more package loading for the more specific tasks

# %%
colab = True

# %%
# for file handling
import os
from pathlib import Path

# Only if working from Google Colab
if colab:
    # Mount the Google Drive to reach its data
    from google.colab import drive
    drive.mount('/content/gdrive')
    os.chdir('/content/gdrive/My Drive')
    # making sure we used the newest versions
    # !pip install --upgrade keras 
    # !pip install --upgrade tensorflow

import sys
sys.path.append('Final_solution')    

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# for numeric calculations
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

# for data handling
import pandas as pd

# for plotting the preprocessed images and the output images and masks
from skimage.measure import find_contours
from skimage.util.montage import montage2d
montage_rgb = lambda x: np.stack([montage2d(x[:, :, :, i]) for i in range(x.shape[3])], -1)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Requirement already up-to-date: keras in /usr/local/lib/python3.6/dist-packages (2.2.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.5)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.6)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.14.6)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.8.0)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.11.0)
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.6/dist-packages (1.12.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.5)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.11.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.6.1)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.32.3)
# Requirement already satisfied, skipping upgrade: tensorboard<1.13.0,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.6)
# Requirement already satisfied, skipping upgrade: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.14.6)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.6.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow) (3.0.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow) (0.14.1)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow) (40.6.2)

# %% [markdown]
# **log dictionary is used to make a log file after every parameters is collected**

# %%
log = {}

# %% [markdown]
# ## Data handling and preprocessing

# %%
from data_utils import load_paths, make_split, make_generators
from keras.applications.vgg16 import preprocess_input
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Define the image parameters and the batch size**

# %%
image_parameters = dict(batch_size = 4,
                        image_size = (224, 224))
image_parameters['input_shape'] = image_parameters['image_size'] + (3,)

log['image_parameters'] = image_parameters

# %%
data_df = load_paths(root='ISIC2018')
train_df, valid_df, test_df = make_split(data_df, train_size=2080, valid_size=264)

print('images:', len(data_df),'train images:', len(train_df), 'valid images:', len(valid_df),'test images:', len(test_df))
data_df.head()
# Out:
# images: 2594 train images: 2080 valid images: 264 test images: 250
#                                              image_path      image_id  \
# 2001  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000000
# 1998  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000001
# 1999  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000003
# 2004  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000004
# 2003  ISIC2018/ISIC2018_Task1-2_Training_Input/ISIC_...  ISIC_0000006
#
#         image_filename                                         task1_path  \
# 2001  ISIC_0000000.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 1998  ISIC_0000001.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 1999  ISIC_0000003.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 2004  ISIC_0000004.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
# 2003  ISIC_0000006.jpg  ISIC2018/ISIC2018_Task1_Training_GroundTruth/I...
#
#                      task1_filename
# 2001  ISIC_0000000_segmentation.png
# 1998  ISIC_0000001_segmentation.png
# 1999  ISIC_0000003_segmentation.png
# 2004  ISIC_0000004_segmentation.png
# 2003  ISIC_0000006_segmentation.png

# %%
# Set the ImageDataGenerator arguments in a dictionary
data_gen_args = dict(data_format = 'channels_last',
                     preprocessing_function = lambda x: preprocess_input(x, data_format='channels_last', mode='tf'))
log['ImageDataGenerator_image_args'] = data_gen_args

# Use the same for the masks and images. (We use same seed value too.)
mask_gen_args = data_gen_args.copy()
mask_gen_args['preprocessing_function'] = lambda x: x/255.0
log['ImageDataGenerator_mask_args'] = mask_gen_args

# %%
# set the flow_from_directory arguments in a dictionary
image_flow_from_dataframe_args = dict(seed = 999,
                                      class_mode=None,
                                      batch_size=image_parameters['batch_size'],
                                      x_col='image_filename',
                                      color_mode = 'rgb',
                                      target_size = image_parameters['image_size'])
log['FlowFromDataframe_image_args'] = image_flow_from_dataframe_args

# use the same arguments for the masks and images. (We use same seed value too.)
mask_flow_from_dataframe_args = image_flow_from_dataframe_args.copy()
mask_flow_from_dataframe_args['x_col'] = 'task1_filename'
mask_flow_from_dataframe_args['color_mode'] = 'grayscale'
log['FlowFromDataframe_mask_args'] = mask_flow_from_dataframe_args

# %%
train_generator, valid_generator, test_generator = make_generators(data_gen_args, mask_gen_args, image_flow_from_dataframe_args, mask_flow_from_dataframe_args, train_df, valid_df, test_df)
# Out:
# Found 2080 images.
# Found 2080 images.
# Found 264 images.
# Found 264 images.
# Found 250 images.
# Found 250 images.

# %%
probe_image, probe_mask = next(test_generator)

print('image', probe_image.shape, probe_image.dtype, probe_image.min(), probe_image.max())
print('mask', probe_mask.shape, probe_mask.dtype, probe_mask.min(), probe_mask.max())

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (20, 10))

ax1.imshow(montage_rgb(probe_image)*0.5+0.5)
ax1.imshow(montage2d(probe_mask[:, :, :, 0]), cmap='gray',alpha=0.3)
ax1.set_title('Images VS Masks')

ax2.imshow(montage_rgb(probe_image)*0.5+0.5)
ax2.set_title('Images')

ax3.imshow(montage2d(probe_mask[:, :, :, 0]), cmap='gray')
ax3.set_title('Masks')

plt.show()
# Out:
# image (4, 224, 224, 3) float32 -1.0 1.0
# mask (4, 224, 224, 1) float32 0.0 1.0

# %% [markdown]
# ## Build the model

# %% [markdown]
# **import the necessary packages**

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, Activation, MaxPooling2D, Concatenate, UpSampling2D, BatchNormalization, Dropout, Add

from keras.applications.vgg16 import VGG16

from model_utils import get_layer_size_dict, concat_layers_dict, save_log

# %% [markdown]
# **Loading the pretrained VGG16 network. This is our encoder part.**

# %%
VGG16_args = dict(input_shape = image_parameters['input_shape'], 
                  include_top = False, 
                  weights = 'imagenet')
log['VGG16_args'] = VGG16_args

vgg16 = VGG16(**VGG16_args)

# %% [markdown]
# **Collect the layer sizes for the decoder part, inspect the structue of the pre-trained model**

# %%
layer_size_dict = get_layer_size_dict(vgg16)

for shape, layer_names in zip(layer_size_dict.keys(), layer_size_dict.values()):
    print('Otuput shape:', shape, 'Layer names:', [temp.name for temp in layer_names])
# Out:
# Otuput shape: (224, 224) Layer names: ['input_1', 'block1_conv1', 'block1_conv2']
# Otuput shape: (112, 112) Layer names: ['block1_pool', 'block2_conv1', 'block2_conv2']
# Otuput shape: (56, 56) Layer names: ['block2_pool', 'block3_conv1', 'block3_conv2', 'block3_conv3']
# Otuput shape: (28, 28) Layer names: ['block3_pool', 'block4_conv1', 'block4_conv2', 'block4_conv3']
# Otuput shape: (14, 14) Layer names: ['block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3']
# Otuput shape: (7, 7) Layer names: ['block5_pool']

# %%
concat_layers = concat_layers_dict(layer_size_dict)

for shape, output in zip(concat_layers.keys(), concat_layers.values()):
    print('Output shape: ', shape, 'Last output: ', output)
# Out:
# Output shape:  (224, 224) Last output:  Tensor("block1_conv2/Relu:0", shape=(?, 224, 224, 64), dtype=float32)
# Output shape:  (112, 112) Last output:  Tensor("block2_conv2/Relu:0", shape=(?, 112, 112, 128), dtype=float32)
# Output shape:  (56, 56) Last output:  Tensor("block3_conv3/Relu:0", shape=(?, 56, 56, 256), dtype=float32)
# Output shape:  (28, 28) Last output:  Tensor("block4_conv3/Relu:0", shape=(?, 28, 28, 512), dtype=float32)
# Output shape:  (14, 14) Last output:  Tensor("block5_conv3/Relu:0", shape=(?, 14, 14, 512), dtype=float32)
# Output shape:  (7, 7) Last output:  Tensor("block5_pool/MaxPool:0", shape=(?, 7, 7, 512), dtype=float32)

# %% [markdown]
# **Build the decoder part**

# %%
x = vgg16.output

# Bottleneck
##########################################################################

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

# Decoder
##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)


##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(512, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Conv2D(256, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(256, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Conv2D(128, (3, 3), padding='same')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(128, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = UpSampling2D(size=(2,2))(x)
x = Conv2D(64, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = Concatenate()([x, concat_layers[tuple(x.get_shape().as_list()[1:3])]])

x = Conv2D(64, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

##########################################################################

x = Conv2D(32, (3, 3), padding='same', kernel_initializer ='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('elu')(x)

x = Conv2D(1, (1, 1), padding='same', kernel_initializer ='he_normal')(x)
x = Activation('sigmoid')(x)

model_final = Model(inputs=vgg16.input, outputs=x)

# %%
model_final.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 7, 7, 512)    2359808     block5_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 7, 7, 512)    2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 7, 7, 512)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 512)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1024) 0           up_sampling2d_1[0][0]
#                                                                  block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 14, 14, 512)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 1024) 0           up_sampling2d_2[0][0]
#                                                                  block4_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 512)  4719104     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 512)  2048        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 512)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  1179904     up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 512)  0           conv2d_4[0][0]
#                                                                  block3_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  1179904     concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 256 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 128 295040      up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112, 112, 256 0           conv2d_6[0][0]
#                                                                  block2_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 112, 112, 128 295040      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 128 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 112, 112, 128 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 224, 224, 128 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 224, 224, 64) 73792       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 224, 224, 128 0           conv2d_8[0][0]
#                                                                  block1_conv2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 224, 224, 64) 73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 224, 224, 64) 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 224, 224, 64) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 224, 224, 32) 18464       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 224, 224, 32) 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 224, 224, 32) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 224, 224, 1)  33          activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 224, 224, 1)  0           conv2d_11[0][0]
# ==================================================================================================
# Total params: 29,636,737
# Trainable params: 29,632,705
# Non-trainable params: 4,032
# __________________________________________________________________________________________________

# %%
from losses import dice_log_bce_loss
from keras.losses import binary_crossentropy

from metrics import dice, jaccard, precision, sensitivity, specificity

from callbacks import ProgeressPlot, ProgressSave
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, ReduceLROnPlateau, Callback, CSVLogger, CallbackList

from keras.optimizers import SGD, Adam, Nadam

# %%
root = 'Final_solution/saved_models'
save_dir =  os.path.join(root, 'Unet_VGG16_simplified_not_freezed_V2')

# Set which layers can learn
for layer in vgg16.layers[1:]:
    layer.trainable = True

# Set callbacks
progress_save = ProgressSave(file_mode='w', save_dir=save_dir, filename='history.csv')

progress_plot = ProgeressPlot(next(test_generator), monitor='val_jaccard', save_dir=save_dir)

ReduceLROnPlateau_args = dict(monitor='val_jaccard',
                              mode='auto',
                              patience=2,
                              factor=0.5,
                              min_lr=0.000001,
                              verbose=1)
log['ReduceLROnPlateau_args'] = ReduceLROnPlateau_args
reduce_lr = ReduceLROnPlateau(**ReduceLROnPlateau_args)

checkpoint_filename = 'not_freezed' + '_{epoch:02d}_{val_loss:.3f}_{val_jaccard:.3f}.hdf5'
checkpoint_path = os.path.join(save_dir, checkpoint_filename)
ModelCheckpoint_args = dict(monitor='val_jaccard',
                            save_best_only=True,  
                            save_weights_only = False,
                            mode='auto',
                            verbose=1)
log['ModelCheckpoint_args'] = ModelCheckpoint_args
checkpoint = ModelCheckpoint(checkpoint_path, **ModelCheckpoint_args)

EarlyStopping_args = dict(monitor='val_jaccard',
                          patience=10,
                          mode='auto',
                          verbose=1)
log['EarlyStopping_args'] = EarlyStopping_args
early = EarlyStopping(**EarlyStopping_args)

# Compile the model
adam = Adam(lr=0.0001)
complie_args = dict(optimizer = adam, 
                    loss = dice_log_bce_loss, 
                    metrics = [dice, jaccard, precision, sensitivity, specificity])
log['complie_args'] = complie_args
model_final.compile(**complie_args)

# Set fit_generator
fit_generator_args = dict(steps_per_epoch=len(train_df) // image_parameters['batch_size'],
                          validation_steps=len(valid_df) // image_parameters['batch_size'],
                          epochs=50,
                          initial_epoch = 0,
                          callbacks = [checkpoint, early, reduce_lr, progress_save, progress_plot])
log['fit_generator_args'] = fit_generator_args
save_log(save_dir, log)
history = model_final.fit_generator(train_generator, validation_data=valid_generator, **fit_generator_args)
# Out:
# ProgressSave: [INFO] Creating file...
# Epoch 1/50
# 520/520 [==============================] - 2209s 4s/step - loss: 0.2484 - dice: 0.8142 - jaccard: 0.7148 - precision: 0.8381 - sensitivity: 0.8561 - specificity: 0.9669 - val_loss: 0.1894 - val_dice: 0.8367 - val_jaccard: 0.7413 - val_precision: 0.8271 - val_sensitivity: 0.8920 - val_specificity: 0.9600
#
# Epoch 00001: val_jaccard improved from -inf to 0.74127, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_01_0.189_0.741.hdf5
# Saved predicted images.
# Epoch 2/50
# 520/520 [==============================] - 751s 1s/step - loss: 0.2070 - dice: 0.8371 - jaccard: 0.7442 - precision: 0.8517 - sensitivity: 0.8741 - specificity: 0.9678 - val_loss: 0.1769 - val_dice: 0.8504 - val_jaccard: 0.7600 - val_precision: 0.8702 - val_sensitivity: 0.8699 - val_specificity: 0.9707
#
# Epoch 00002: val_jaccard improved from 0.74127 to 0.76000, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_02_0.177_0.760.hdf5
# Saved predicted images.
# Epoch 3/50
# 520/520 [==============================] - 755s 1s/step - loss: 0.1887 - dice: 0.8481 - jaccard: 0.7581 - precision: 0.8632 - sensitivity: 0.8793 - specificity: 0.9691 - val_loss: 0.2733 - val_dice: 0.7794 - val_jaccard: 0.6740 - val_precision: 0.7551 - val_sensitivity: 0.8852 - val_specificity: 0.9172
#
# Epoch 00003: val_jaccard did not improve from 0.76000
# Epoch 4/50
# 520/520 [==============================] - 752s 1s/step - loss: 0.1706 - dice: 0.8596 - jaccard: 0.7726 - precision: 0.8726 - sensitivity: 0.8866 - specificity: 0.9696 - val_loss: 0.1450 - val_dice: 0.8742 - val_jaccard: 0.7934 - val_precision: 0.8820 - val_sensitivity: 0.8994 - val_specificity: 0.9691
#
# Epoch 00004: val_jaccard improved from 0.76000 to 0.79338, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_04_0.145_0.793.hdf5
# Saved predicted images.
# Epoch 5/50
# 520/520 [==============================] - 753s 1s/step - loss: 0.1599 - dice: 0.8657 - jaccard: 0.7798 - precision: 0.8775 - sensitivity: 0.8894 - specificity: 0.9694 - val_loss: 0.1482 - val_dice: 0.8732 - val_jaccard: 0.7900 - val_precision: 0.8832 - val_sensitivity: 0.8930 - val_specificity: 0.9731
#
# Epoch 00005: val_jaccard did not improve from 0.79338
# Epoch 6/50
# 520/520 [==============================] - 757s 1s/step - loss: 0.1539 - dice: 0.8710 - jaccard: 0.7872 - precision: 0.8820 - sensitivity: 0.8933 - specificity: 0.9682 - val_loss: 0.1491 - val_dice: 0.8679 - val_jaccard: 0.7835 - val_precision: 0.8704 - val_sensitivity: 0.9009 - val_specificity: 0.9688
#
# Epoch 00006: val_jaccard did not improve from 0.79338
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 7/50
# 520/520 [==============================] - 754s 1s/step - loss: 0.1261 - dice: 0.8898 - jaccard: 0.8126 - precision: 0.8994 - sensitivity: 0.9036 - specificity: 0.9709 - val_loss: 0.1370 - val_dice: 0.8815 - val_jaccard: 0.8026 - val_precision: 0.9130 - val_sensitivity: 0.8790 - val_specificity: 0.9792
#
# Epoch 00007: val_jaccard improved from 0.79338 to 0.80263, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_07_0.137_0.803.hdf5
# Saved predicted images.
# Epoch 8/50
# 520/520 [==============================] - 749s 1s/step - loss: 0.1165 - dice: 0.8958 - jaccard: 0.8210 - precision: 0.9028 - sensitivity: 0.9097 - specificity: 0.9709 - val_loss: 0.1348 - val_dice: 0.8810 - val_jaccard: 0.8028 - val_precision: 0.8900 - val_sensitivity: 0.9010 - val_specificity: 0.9630
#
# Epoch 00008: val_jaccard improved from 0.80263 to 0.80275, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_08_0.135_0.803.hdf5
# Saved predicted images.
# Epoch 9/50
# 520/520 [==============================] - 757s 1s/step - loss: 0.1079 - dice: 0.9020 - jaccard: 0.8292 - precision: 0.9094 - sensitivity: 0.9119 - specificity: 0.9708 - val_loss: 0.1266 - val_dice: 0.8863 - val_jaccard: 0.8092 - val_precision: 0.8999 - val_sensitivity: 0.8988 - val_specificity: 0.9713
#
# Epoch 00009: val_jaccard improved from 0.80275 to 0.80919, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_09_0.127_0.809.hdf5
# Saved predicted images.
# Epoch 10/50
# 520/520 [==============================] - 751s 1s/step - loss: 0.1054 - dice: 0.9041 - jaccard: 0.8324 - precision: 0.9110 - sensitivity: 0.9135 - specificity: 0.9712 - val_loss: 0.1453 - val_dice: 0.8767 - val_jaccard: 0.7989 - val_precision: 0.8790 - val_sensitivity: 0.9106 - val_specificity: 0.9748
#
# Epoch 00010: val_jaccard did not improve from 0.80919
# Epoch 11/50
# 520/520 [==============================] - 752s 1s/step - loss: 0.1007 - dice: 0.9076 - jaccard: 0.8375 - precision: 0.9143 - sensitivity: 0.9157 - specificity: 0.9727 - val_loss: 0.1322 - val_dice: 0.8837 - val_jaccard: 0.8063 - val_precision: 0.8891 - val_sensitivity: 0.9067 - val_specificity: 0.9655
#
# Epoch 00011: val_jaccard did not improve from 0.80919
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 12/50
# 520/520 [==============================] - 754s 1s/step - loss: 0.0882 - dice: 0.9172 - jaccard: 0.8518 - precision: 0.9222 - sensitivity: 0.9230 - specificity: 0.9724 - val_loss: 0.1336 - val_dice: 0.8891 - val_jaccard: 0.8151 - val_precision: 0.9250 - val_sensitivity: 0.8819 - val_specificity: 0.9820
#
# Epoch 00012: val_jaccard improved from 0.80919 to 0.81506, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_12_0.134_0.815.hdf5
# Saved predicted images.
# Epoch 13/50
# 520/520 [==============================] - 753s 1s/step - loss: 0.0818 - dice: 0.9227 - jaccard: 0.8603 - precision: 0.9266 - sensitivity: 0.9275 - specificity: 0.9745 - val_loss: 0.1275 - val_dice: 0.8896 - val_jaccard: 0.8150 - val_precision: 0.8951 - val_sensitivity: 0.9117 - val_specificity: 0.9678
#
# Epoch 00013: val_jaccard did not improve from 0.81506
# Epoch 14/50
# 520/520 [==============================] - 754s 1s/step - loss: 0.0766 - dice: 0.9266 - jaccard: 0.8665 - precision: 0.9295 - sensitivity: 0.9312 - specificity: 0.9746 - val_loss: 0.1399 - val_dice: 0.8880 - val_jaccard: 0.8153 - val_precision: 0.9006 - val_sensitivity: 0.9063 - val_specificity: 0.9743
#
# Epoch 00014: val_jaccard improved from 0.81506 to 0.81531, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_14_0.140_0.815.hdf5
# Saved predicted images.
# Epoch 15/50
# 520/520 [==============================] - 750s 1s/step - loss: 0.0732 - dice: 0.9292 - jaccard: 0.8706 - precision: 0.9322 - sensitivity: 0.9331 - specificity: 0.9765 - val_loss: 0.1272 - val_dice: 0.8945 - val_jaccard: 0.8228 - val_precision: 0.9131 - val_sensitivity: 0.9016 - val_specificity: 0.9753
#
# Epoch 00015: val_jaccard improved from 0.81531 to 0.82281, saving model to Final_solution/saved_models/Unet_VGG16_simplified_not_freezed_V2/not_freezed_15_0.127_0.823.hdf5
# Saved predicted images.
# Epoch 16/50
# 520/520 [==============================] - 754s 1s/step - loss: 0.0695 - dice: 0.9323 - jaccard: 0.8758 - precision: 0.9347 - sensitivity: 0.9361 - specificity: 0.9770 - val_loss: 0.1363 - val_dice: 0.8925 - val_jaccard: 0.8210 - val_precision: 0.9231 - val_sensitivity: 0.8890 - val_specificity: 0.9784
#
# Epoch 00016: val_jaccard did not improve from 0.82281
# Epoch 17/50
# 520/520 [==============================] - 751s 1s/step - loss: 0.0651 - dice: 0.9359 - jaccard: 0.8819 - precision: 0.9377 - sensitivity: 0.9395 - specificity: 0.9776 - val_loss: 0.1344 - val_dice: 0.8923 - val_jaccard: 0.8198 - val_precision: 0.9132 - val_sensitivity: 0.8963 - val_specificity: 0.9716
#
# Epoch 00017: val_jaccard did not improve from 0.82281
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 18/50
# 520/520 [==============================] - 757s 1s/step - loss: 0.0583 - dice: 0.9418 - jaccard: 0.8919 - precision: 0.9437 - sensitivity: 0.9439 - specificity: 0.9801 - val_loss: 0.1422 - val_dice: 0.8913 - val_jaccard: 0.8195 - val_precision: 0.9131 - val_sensitivity: 0.8972 - val_specificity: 0.9788
#
# Epoch 00018: val_jaccard did not improve from 0.82281
# Epoch 19/50
# 520/520 [==============================] - 749s 1s/step - loss: 0.0535 - dice: 0.9462 - jaccard: 0.8994 - precision: 0.9469 - sensitivity: 0.9487 - specificity: 0.9810 - val_loss: 0.1385 - val_dice: 0.8934 - val_jaccard: 0.8221 - val_precision: 0.9097 - val_sensitivity: 0.9042 - val_specificity: 0.9780
#
# Epoch 00019: val_jaccard did not improve from 0.82281
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 20/50
# 520/520 [==============================] - 756s 1s/step - loss: 0.0488 - dice: 0.9506 - jaccard: 0.9071 - precision: 0.9512 - sensitivity: 0.9523 - specificity: 0.9821 - val_loss: 0.1396 - val_dice: 0.8936 - val_jaccard: 0.8226 - val_precision: 0.9154 - val_sensitivity: 0.8985 - val_specificity: 0.9788
#
# Epoch 00020: val_jaccard did not improve from 0.82281
# Epoch 21/50
# 520/520 [==============================] - 750s 1s/step - loss: 0.0459 - dice: 0.9532 - jaccard: 0.9116 - precision: 0.9532 - sensitivity: 0.9549 - specificity: 0.9833 - val_loss: 0.1434 - val_dice: 0.8920 - val_jaccard: 0.8204 - val_precision: 0.9064 - val_sensitivity: 0.9058 - val_specificity: 0.9775
#
# Epoch 00021: val_jaccard did not improve from 0.82281
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 22/50
# 520/520 [==============================] - 751s 1s/step - loss: 0.0438 - dice: 0.9550 - jaccard: 0.9150 - precision: 0.9546 - sensitivity: 0.9571 - specificity: 0.9838 - val_loss: 0.1467 - val_dice: 0.8925 - val_jaccard: 0.8213 - val_precision: 0.9126 - val_sensitivity: 0.9005 - val_specificity: 0.9797
#
# Epoch 00022: val_jaccard did not improve from 0.82281
# Epoch 23/50
# 520/520 [==============================] - 756s 1s/step - loss: 0.0425 - dice: 0.9563 - jaccard: 0.9172 - precision: 0.9556 - sensitivity: 0.9583 - specificity: 0.9842 - val_loss: 0.1453 - val_dice: 0.8932 - val_jaccard: 0.8226 - val_precision: 0.9154 - val_sensitivity: 0.8985 - val_specificity: 0.9790
#
# Epoch 00023: val_jaccard did not improve from 0.82281
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 24/50
# 520/520 [==============================] - 750s 1s/step - loss: 0.0414 - dice: 0.9576 - jaccard: 0.9194 - precision: 0.9575 - sensitivity: 0.9587 - specificity: 0.9848 - val_loss: 0.1444 - val_dice: 0.8927 - val_jaccard: 0.8214 - val_precision: 0.9060 - val_sensitivity: 0.9070 - val_specificity: 0.9769
#
# Epoch 00024: val_jaccard did not improve from 0.82281
# Epoch 25/50
# 520/520 [==============================] - 757s 1s/step - loss: 0.0407 - dice: 0.9582 - jaccard: 0.9205 - precision: 0.9578 - sensitivity: 0.9597 - specificity: 0.9848 - val_loss: 0.1459 - val_dice: 0.8924 - val_jaccard: 0.8213 - val_precision: 0.9088 - val_sensitivity: 0.9040 - val_specificity: 0.9772
#
# Epoch 00025: val_jaccard did not improve from 0.82281
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 00025: early stopping

# %% [markdown]
# ## Visualize the results

# %%
# load back the best weights
root = 'Final_solution/saved_models'
directory = 'Unet_VGG16_simplified_not_freezed'
filename = 'not_freezed_15_0.127_0.823.hdf5'

file_path = os.path.join(root, directory)
file_path = os.path.join(file_path, filename)

model_final.load_weights(file_path)

# %%
test_images, test_masks = next(test_generator)
test_predictions = model_final.predict(test_images)

print('Batch size:', test_images.shape[0])
for i in range(test_images.shape[0]):
    print('# in batch:', i+1, ', max, min value: ', test_predictions[i,:,:,:].max(), test_predictions[i,:,:,:].min())

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (40, 10))

ax1.imshow(montage_rgb(test_images)*0.5+0.5)
ax1.imshow(montage2d(test_predictions[:, :, :, 0]), cmap='gray', alpha=0.3)
ax1.set_title('Image VS prediction');

contours_masks = find_contours(montage2d(test_masks[:, :, :, 0]), level=0.99)
for contour in contours_masks:
  ax1.plot(contour[:, 1], contour[:, 0], "--r", linewidth=0.5)

contours_predictions = find_contours(montage2d(test_predictions[:, :, :, 0]), level=0.9)
for contour in contours_predictions:
  ax1.plot(contour[:, 1], contour[:, 0], "--b", linewidth=0.5)
  
ax2.imshow(montage_rgb(test_images)*0.5+0.5)
ax2.set_title('Original images');
  
ax3.imshow(montage2d(test_predictions[:, :, :, 0]), cmap = 'gray')
ax3.set_title('Predictions');

ax4.imshow(montage2d(test_masks[:, :, :, 0]), cmap = 'gray')
ax4.set_title('Original Masks');

# %% [markdown]
# ## Test the model on test data

# %% [markdown]
# **Get the best model checkpoint files**

# %%
root = 'Final_solution/saved_models'
directory = 'Unet_VGG16_simplified_freezed'
filename = 'freezed_17_0.210_0.770.hdf5'

save_file_freezed_directory = os.path.join(root, directory)
save_file_freezed_path = os.path.join(save_file_freezed_directory, filename)

root = 'Final_solution/saved_models'
directory = 'Unet_VGG16_simplified_not_freezed'
filename = 'not_freezed_15_0.127_0.823.hdf5'

save_file_not_freezed_directory = os.path.join(root, directory)
save_file_not_freezed_path = os.path.join(save_file_not_freezed_directory, filename)

# %% [markdown]
# **Evaluate goal metrics on test data**

# %%
from eval_utils import soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold
from keras.models import load_model
from keras.optimizers import Adam

# %%
model_final = load_model(save_file_not_freezed_path, compile=False)

adam = Adam(lr=0.0001)
model_final.compile(optimizer = adam, 
                    loss = dice_log_bce_loss, 
                    metrics = [soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold])

# %%
results = model_final.evaluate_generator(test_generator, steps=test_df.shape[0] // image_parameters['batch_size'], verbose=1)

for k,v in zip(model_final.metrics_names, results):
    print(k,'%2.4f' % v)
# Out:
# 62/62 [==============================] - 72s 1s/step
# loss 0.1618
# soft_jaccard 0.8159
# soft_jaccard_threshold 0.7586
# hard_jaccard 0.8223
# hard_jaccard_threshold 0.7666

# %% [markdown]
# **Plot the history**

# %%
result_freezed_df = pd.read_csv(os.path.join(save_file_freezed_directory, 'history.csv'))
result_not_freezed_df = pd.read_csv(os.path.join(save_file_not_freezed_directory, 'history.csv'))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = ['val_jaccard', 'val_dice', 'val_precision', 'val_sensitivity', 'val_specificity'], ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = ['val_jaccard', 'val_dice', 'val_precision', 'val_sensitivity', 'val_specificity'], ax=ax2);

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = 'val_loss', ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = 'val_loss', ax=ax2);

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

result_freezed_df.plot(x = 'epoch', y = 'lr', ax=ax1);
result_not_freezed_df.plot(x = 'epoch', y = 'lr', ax=ax2);
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Test the loss functions

# %%
from keras.losses import binary_crossentropy
from losses import dice_log_bce_loss
from eval_utils import soft_jaccard, soft_jaccard_threshold, hard_jaccard, hard_jaccard_threshold
from metrics import dice, jaccard, precision, sensitivity, specificity

# %%
test_images, test_masks = next(test_generator)
test_predictions = model_final.predict(test_images)

y_pred = tf.convert_to_tensor(test_predictions, dtype=tf.float32)
y_true = tf.convert_to_tensor(test_masks, dtype=tf.float32)

# %%
import tensorflow as tf
sess = tf.Session()

from keras import backend as K
K.set_session(sess)

# %%
def hard_jaccard_threshold(y_true, y_pred, threshold=0.65, pixel_threshold=0.7):

    y_pred = K.greater(y_pred, pixel_threshold)
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jaccard_index = (intersection / union)
    
    temp = K.greater(jaccard_index, threshold)
    temp = K.cast(temp, 'float32')

    return (temp*jaccard_index), temp, jaccard_index


result = sess.run(hard_jaccard_threshold(y_true, y_pred))

print(result)
# Out:
# (array([0.93733454, 0.8901515 , 0.77291304, 0.9549443 ], dtype=float32), array([1., 1., 1., 1.], dtype=float32), array([0.93733454, 0.8901515 , 0.77291304, 0.9549443 ], dtype=float32))

# %%
def hard_jaccard(y_true, y_pred, pixel_threshold=0.7):

    y_pred = K.greater(y_pred, pixel_threshold)
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jacard_index = (intersection / union)
    
    return jacard_index
  
result = sess.run(hard_jaccard(y_true, y_pred))

print(result)
# Out:
# [0.93733454 0.8901515  0.77291304 0.9549443 ]

# %%
result = sess.run(jaccard(y_true, y_pred))

print(result)
# Out:
# [0.92846084 0.8695071  0.7862567  0.9272945 ]

# %%
def soft_jaccard(y_true, y_pred):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    y_true_abs = K.sum(y_true, axis=[1,2,3])
    y_pred_abs = K.sum(y_pred, axis=[1,2,3])
    union = y_true_abs + y_pred_abs - intersection
    jacard_index = (intersection / union)
    
    return jacard_index

result = sess.run(soft_jaccard(y_true, y_pred))

print(result)
# Out:
# [0.92846084 0.8695071  0.7862567  0.9272945 ]
